# %% [markdown]
# Check feature extraction tutorial first before this.
#
# After feature extraction, it will generate a csv file that has:
# 1. Term
# 2. Number of legitimate emails that word occurred in
# 3. Number of spam emails that word occurred in
# 4. Mutual Information Count

# %%
#imports
import pandas as pd

# %% [markdown]
# After computing the mutual information score of each term, we can now extract the top n highest terms based on the MI to be used as the features for the classifier. The paper used 50-700 features, step 50.

# %%
numMI = [50,100,150,200,250,300,350,400,450,500,550,600,650,700]
corpus = ['bare','lemm', 'lemm_stop', 'stop']

for corp in corpus:
    for num in numMI:
        termMIList = pd.read_csv("Features/"+corp+"/"+corp+"termMI.csv", index_col = 0)
        terms = pd.DataFrame(termMIList.head(n=num)).to_csv("MI/"+corp+"/"+str(num)+"terms.csv")
print ("Done, check MI folder")
# Out:
# Done, check MI folder

# %% [markdown]
# in order to classify, insert formula hereeee

# %%
import math
from decimal import *

getcontext().prec = 256


# A = P(X=x|C=c)
# P(A|B), is equal to P(AB)/P(B).
# P(A) = (Total number of times x occurred/total number of term occurrence in the corpus)
# P(B) = (Total number of email c in the corpus /total number of documents in the corpus)
#termProb = total number of times x occurred  in document


def computeTermGivenClass(probClass, terms, totalTerms):
    prob = Decimal(1.0)
    for x in terms:
        a = (Decimal(x)/Decimal(totalTerms))
        prob = (Decimal(prob) * (Decimal(a)/Decimal(probClass)))
    
    return prob

#B = P(X=x) = (Total number of times x occurred in the corpus)/(Total number of word occurrence in the corpus)
#C = P(C=c) = (Total number of documents that are c in the corpus)/(Total number of documents in the corpus)
          
def computeProbability(isComputingSpam, totalDoc, spamTerms, legitTerms, totalTerms, totalLegitCount, totalSpamCount):
      
    probSpam = (totalSpamCount/totalDoc)
    probLegit = (totalLegitCount/totalDoc)
    
    givenSpam =  (Decimal(probSpam) * computeTermGivenClass(probSpam, spamTerms, totalTerms))
    givenLegit = (Decimal(probLegit) * computeTermGivenClass(probLegit, legitTerms, totalTerms))
    
    if isComputingSpam == True:
        numerator =  givenSpam
    else:
        numerator =  givenLegit
            
    denominator = Decimal(givenSpam) + Decimal(givenLegit)
    
    probClass = Decimal(numerator/denominator)
    return probClass

# %%
import re
def extractWords(filepath):
    file = open(filepath, 'r')
    # .lower() returns a version with all upper case characters replaced with lower case characters.
    text = file.read().lower()
    file.close()
    # replaces anything that is not a lowercase letter, a space, or an apostrophe with a space:
    text = re.sub('[^a-z]+', " ", text)
    words = list(text.split())
    
     # remove duplicate words in the list
    words = list(set(words))
    # removes words that are less than 4 letters/characters
    words =  [i for i in words if len(i) >= 4] 
    return words;

def findTermCounts(terms, docTerms):
    return terms.loc[terms['Term'].isin(docTerms)]

# %%
import re

numFeatures = [50,100,150,200,250,300,350,400,450,500,550,600,650,700]
# 0.5 - 1, 0.9 - 9, 0.999 - 999
threshold = [0.5, 0.9, 0.999]

pattern = re.compile("\d+-\d+msg\d+.txt")

def classify(corp):
    #load the vocabulary/word/term list for the entire corpus from file
    corpusTerms = pd.read_csv("Features/"+corp.corpusName+"/baretermMI.csv", index_col = 0)
    totalLegitTerms = corpusTerms['LegitCount'].sum(axis=0)
    totalSpamTerms = corpusTerms['SpamCount'].sum(axis=0)

    print ("Classifying Documents in Corpus: ", corp.corpusName)
    
    totalDoc = corp.totalEmailCtr
    totalLegitCount = corp.legitEmailCtr
    totalSpamCount = corp.spamEmailCtr
    
    for num in numFeatures:
        terms = pd.read_csv("MI/"+corp.corpusName+"/"+str(num)+"terms.csv", index_col = 0)
        print ("Using", len(terms), " of Features") 
        spamCount = terms['SpamCount'].tolist()
        legitCount = terms['LegitCount'].tolist()
        totalTerms = totalLegitCount + totalSpamCount
        
        for t in threshold:
            actual = []
            predicted = []
            #for each subdirectory in a corpus (folders - part 1 - 10)
            for subdir, dirs, files in os.walk(rootdir):
            #for each file in a folder
                for file in files:  
                    filepath = subdir +"/"+file       
                    
                    docTerms = extractWords(filepath)
                    rowTerms = findTermCounts(terms, docTerms)
                    PCSpam = Decimal(computeProbability(True, totalDoc, spamCount, legitCount, 
                                                        totalTerms, totalLegitCount, totalSpamCount))
                    PCLegit = Decimal(computeProbability(False, totalDoc, spamCount, legitCount, 
                                                        totalTerms, totalLegitCount, totalSpamCount))
                    
                    if PCSpam/PCLegit > t:
                        p = 0
                    else:
                        p = 1
                        
                    if pattern.match(file): 
                        a = 1
                    else:
                        a = 0
                    
                    actual.append(a)
                    predicted.append(p)
                    
        results = pandas.DataFrame(
            {'Actual': actual,
             'Predicted' : predicted,
            })

        #save the Term MI to CSV (so we can access it later)
        results.to_csv("Classified/"+corp+"/"+str(num)+"/"+str(t)+"_results.csv")
        print("File Saved: ", corp, num, t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-4ae09126a237> in <module>()
#       1 import re
#       2 #load the vocabulary/word/term list for the entire corpus from file
# ----> 3 corpusTerms = pd.read_csv("Features/"+corp+"/baretermMI.csv", index_col = 0)
#       4 totalLegitTerms = corpusTerms['LegitCount'].sum(axis=0)
#       5 totalSpamTerms = corpusTerms['SpamCount'].sum(axis=0)
#
# TypeError: Can't convert 'CorpusData' object to str implicitly

# %%
# create a class for the the Corpus data, it will store the total number of emails in the corpus, 
# along with the total number of spam and legit emails
class CorpusData: 
    corpusName = ""
    totalEmailCtr = 0
    spamEmailCtr = 0
    legitEmailCtr = 0

    def __init__(self, corpusName, totalEmailCtr, spamEmailCtr, legitEmailCtr):
        self.corpusName = corpusName
        self.totalEmailCtr = totalEmailCtr
        self.spamEmailCtr = spamEmailCtr
        self.legitEmailCtr = legitEmailCtr
        
# total emails, total spam emails, total legit emails
bare = CorpusData("bare", 2515, 304, 2211)
lemm = CorpusData("lemm", 2776, 452, 2324)
lemm_stop = CorpusData("lemm_stop", 2609, 281, 2409)
stop = CorpusData("stop", 2341, 481, 1860)

corpusDataList = []

corpusDataList.append(bare)
corpusDataList.append(lemm)
corpusDataList.append(lemm_stop)
corpusDataList.append(stop)

for corp in corpusDataList:
    classify(corp)
# Out:
# Classifying Documents in Corpus:  bare
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-5cce8825ca63> in <module>()
#      27
#      28 for corp in corpusDataList:
# ---> 29     classify(corp)
#      30
#
# <ipython-input-47-df7ee199df78> in classify(corp)
#      20
#      21     for num in numFeatures:
# ---> 22         terms = pd.read_csv("MI/"+corp+"/"+str(num)+"terms.csv", index_col = 0)
#      23         print ("Using", len(terms), " of Features")
#      24         spamCount = terms['SpamCount'].tolist()
#
# TypeError: Can't convert 'CorpusData' object to str implicitly

# %%
import os
rootdir = "Emails/"

#for each subdirectory in a corpus (folders - part 1 - 10)
for subdir, dirs, files in os.walk(rootdir):
#for each file in a folder
    for file in files:  
        filepath = subdir +"/"+file    
        print (filepath)
# Out:
# Emails/stop/part4/6-812msg1.txt
# Emails/stop/part4/6-327msg3.txt
# Emails/stop/part4/8-1023msg1.txt
# Emails/stop/part4/6-468msg3.txt
# Emails/stop/part4/6-256msg1.txt
# Emails/stop/part4/8-1043msg2.txt
# Emails/stop/part4/6-861msg1.txt
# Emails/stop/part4/8-1063msg2.txt
# Emails/stop/part4/6-42msg2.txt
# Emails/stop/part4/6-400msg2.txt
# Emails/stop/part4/6-318msg1.txt
# Emails/stop/part4/6-245msg1.txt
# Emails/stop/part4/6-348msg1.txt
# Emails/stop/part4/6-377msg1.txt
# Emails/stop/part4/6-273msg1.txt
# Emails/stop/part4/6-309msg1.txt
# Emails/stop/part4/6-408msg1.txt
# Emails/stop/part4/6-437msg2.txt
# Emails/stop/part4/6-887msg1.txt
# Emails/stop/part4/6-863msg1.txt
# Emails/stop/part4/6-843msg1.txt
# Emails/stop/part4/6-853msg1.txt
# Emails/stop/part4/6-359msg3.txt
# Emails/stop/part4/6-437msg3.txt
# Emails/stop/part4/6-327msg4.txt
# Emails/stop/part4/6-243msg1.txt
# Emails/stop/part4/6-396msg1.txt
# Emails/stop/part4/6-417msg1.txt
# Emails/stop/part4/6-266msg1.txt
# Emails/stop/part4/8-1066msg2.txt
# Emails/stop/part4/6-456msg1.txt
# Emails/stop/part4/6-790msg3.txt
# Emails/stop/part4/6-93msg1.txt
# Emails/stop/part4/spmsgb106.txt
# Emails/stop/part4/6-77msg1.txt
# Emails/stop/part4/6-371msg1.txt
# Emails/stop/part4/6-329msg3.txt
# Emails/stop/part4/6-435msg1.txt
# Emails/stop/part4/spmsgb113.txt
# Emails/stop/part4/6-410msg1.txt
# Emails/stop/part4/8-1071msg1.txt
# Emails/stop/part4/6-375msg1.txt
# Emails/stop/part4/spmsgb1.txt
# Emails/stop/part4/spmsgb12.txt
# Emails/stop/part4/6-280msg1.txt
# Emails/stop/part4/6-70msg1.txt
# Emails/stop/part4/6-248msg1.txt
# Emails/stop/part4/6-996msg1.txt
# Emails/stop/part4/spmsgb104.txt
# Emails/stop/part4/6-785msg1.txt
# Emails/stop/part4/6-390msg3.txt
# Emails/stop/part4/6-420msg2.txt
# Emails/stop/part4/8-1074msg1.txt
# Emails/stop/part4/6-925msg1.txt
# Emails/stop/part4/6-902msg1.txt
# Emails/stop/part4/spmsgb110.txt
# Emails/stop/part4/6-432msg2.txt
# Emails/stop/part4/8-1005msg2.txt
# Emails/stop/part4/6-849msg1.txt
# Emails/stop/part4/spmsga93.txt
# Emails/stop/part4/spmsgb107.txt
# Emails/stop/part4/6-341msg3.txt
# Emails/stop/part4/6-41msg1.txt
# Emails/stop/part4/spmsga9.txt
# Emails/stop/part4/6-425msg1.txt
# Emails/stop/part4/8-1005msg1.txt
# Emails/stop/part4/6-373msg3.txt
# Emails/stop/part4/6-468msg1.txt
# Emails/stop/part4/spmsgb116.txt
# Emails/stop/part4/6-373msg2.txt
# Emails/stop/part4/6-843msg2.txt
# Emails/stop/part4/6-789msg1.txt
# Emails/stop/part4/spmsgb101.txt
# Emails/stop/part4/6-359msg2.txt
# Emails/stop/part4/6-334msg1.txt
# Emails/stop/part4/6-317msg1.txt
# Emails/stop/part4/6-390msg1.txt
# Emails/stop/part4/6-65msg1.txt
# Emails/stop/part4/6-248msg2.txt
# Emails/stop/part4/6-844msg1.txt
# Emails/stop/part4/6-289msg3.txt
# Emails/stop/part4/spmsgb121.txt
# Emails/stop/part4/6-418msg1.txt
# Emails/stop/part4/spmsgb118.txt
# Emails/stop/part4/6-72msg1.txt
# Emails/stop/part4/spmsgb119.txt
# Emails/stop/part4/spmsga84.txt
# Emails/stop/part4/spmsga8.txt
# Emails/stop/part4/6-385msg1.txt
# Emails/stop/part4/6-290msg1.txt
# Emails/stop/part4/6-966msg1.txt
# Emails/stop/part4/6-326msg3.txt
# Emails/stop/part4/6-271msg1.txt
# Emails/stop/part4/6-45msg1.txt
# Emails/stop/part4/spmsga89.txt
# Emails/stop/part4/6-241msg2.txt
# Emails/stop/part4/6-42msg1.txt
# Emails/stop/part4/6-357msg2.txt
# Emails/stop/part4/8-1028msg1.txt
# Emails/stop/part4/6-963msg1.txt
# Emails/stop/part4/6-325msg2.txt
# Emails/stop/part4/6-241msg3.txt
# Emails/stop/part4/6-329msg2.txt
# Emails/stop/part4/6-858msg1.txt
# Emails/stop/part4/6-51msg1.txt
# Emails/stop/part4/6-790msg1.txt
# Emails/stop/part4/6-789msg2.txt
# Emails/stop/part4/6-42msg3.txt
# Emails/stop/part4/6-475msg2.txt
# Emails/stop/part4/spmsga98.txt
# Emails/stop/part4/6-57msg1.txt
# Emails/stop/part4/8-1043msg1.txt
# Emails/stop/part4/6-901msg1.txt
# Emails/stop/part4/6-268msg1.txt
# Emails/stop/part4/6-291msg1.txt
# Emails/stop/part4/6-76msg1.txt
# Emails/stop/part4/6-315msg1.txt
# Emails/stop/part4/6-471msg1.txt
# Emails/stop/part4/6-859msg1.txt
# Emails/stop/part4/6-413msg3.txt
# Emails/stop/part4/6-413msg2.txt
# Emails/stop/part4/6-388msg1.txt
# Emails/stop/part4/8-1063msg1.txt
# Emails/stop/part4/6-416msg1.txt
# Emails/stop/part4/spmsga86.txt
# Emails/stop/part4/6-400msg3.txt
# Emails/stop/part4/6-341msg2.txt
# Emails/stop/part4/spmsgb111.txt
# Emails/stop/part4/8-1049msg1.txt
# Emails/stop/part4/6-341msg1.txt
# Emails/stop/part4/6-333msg2.txt
# Emails/stop/part4/6-325msg3.txt
# Emails/stop/part4/6-393msg1.txt
# Emails/stop/part4/6-304msg1.txt
# Emails/stop/part4/6-289msg1.txt
# Emails/stop/part4/spmsga80.txt
# Emails/stop/part4/8-1074msg2.txt
# Emails/stop/part4/8-1023msg2.txt
# Emails/stop/part4/6-778msg1.txt
# Emails/stop/part4/6-434msg1.txt
# Emails/stop/part4/6-463msg1.txt
# Emails/stop/part4/6-303msg1.txt
# Emails/stop/part4/6-326msg2.txt
# Emails/stop/part4/6-266msg3.txt
# Emails/stop/part4/spmsgb114.txt
# Emails/stop/part4/6-357msg1.txt
# Emails/stop/part4/spmsga82.txt
# Emails/stop/part4/6-54msg1.txt
# Emails/stop/part4/6-52msg1.txt
# Emails/stop/part4/6-844msg2.txt
# Emails/stop/part4/spmsga94.txt
# Emails/stop/part4/6-429msg1.txt
# Emails/stop/part4/6-413msg1.txt
# Emails/stop/part4/6-325msg1.txt
# Emails/stop/part4/spmsga83.txt
# Emails/stop/part4/6-899msg1.txt
# Emails/stop/part4/6-762msg3.txt
# Emails/stop/part4/6-420msg1.txt
# Emails/stop/part4/6-426msg1.txt
# Emails/stop/part4/6-282msg1.txt
# Emails/stop/part4/6-257msg1.txt
# Emails/stop/part4/6-378msg1.txt
# Emails/stop/part4/spmsga99.txt
# Emails/stop/part4/6-422msg1.txt
# Emails/stop/part4/8-1053msg1.txt
# Emails/stop/part4/6-860msg1.txt
# Emails/stop/part4/6-327msg5.txt
# Emails/stop/part4/6-326msg1.txt
# Emails/stop/part4/6-862msg1.txt
# Emails/stop/part4/spmsgb112.txt
# Emails/stop/part4/6-437msg1.txt
# Emails/stop/part4/6-245msg3.txt
# Emails/stop/part4/6-33msg1.txt
# Emails/stop/part4/6-406msg1.txt
# Emails/stop/part4/6-333msg1.txt
# Emails/stop/part4/spmsga96.txt
# Emails/stop/part4/6-475msg3.txt
# Emails/stop/part4/6-357msg3.txt
# Emails/stop/part4/6-367msg1.txt
# Emails/stop/part4/6-36msg1.txt
# Emails/stop/part4/6-390msg2.txt
# Emails/stop/part4/6-373msg1.txt
# Emails/stop/part4/6-419msg1.txt
# Emails/stop/part4/6-991msg1.txt
# Emails/stop/part4/6-378msg2.txt
# Emails/stop/part4/spmsga88.txt
# Emails/stop/part4/spmsgb105.txt
# Emails/stop/part4/6-4msg2.txt
# Emails/stop/part4/6-396msg3.txt
# Emails/stop/part4/6-81msg1.txt
# Emails/stop/part4/6-997msg1.txt
# Emails/stop/part4/6-55msg1.txt
# Emails/stop/part4/6-396msg2.txt
# Emails/stop/part4/6-274msg1.txt
# Emails/stop/part4/6-353msg3.txt
# Emails/stop/part4/6-422msg3.txt
# Emails/stop/part4/spmsga81.txt
# Emails/stop/part4/6-333msg3.txt
# Emails/stop/part4/spmsgb10.txt
# Emails/stop/part4/6-432msg3.txt
# Emails/stop/part4/6-254msg1.txt
# Emails/stop/part4/spmsga90.txt
# Emails/stop/part4/spmsga97.txt
# Emails/stop/part4/6-273msg3.txt
# Emails/stop/part4/6-411msg1.txt
# Emails/stop/part4/6-270msg1.txt
# Emails/stop/part4/6-252msg1.txt
# Emails/stop/part4/6-790msg2.txt
# Emails/stop/part4/6-420msg3.txt
# Emails/stop/part4/6-778msg3.txt
# Emails/stop/part4/6-848msg1.txt
# Emails/stop/part4/6-459msg1.txt
# Emails/stop/part4/spmsgb115.txt
# Emails/stop/part4/6-31msg1.txt
# Emails/stop/part4/6-972msg1.txt
# Emails/stop/part4/6-28msg1.txt
# Emails/stop/part4/6-4msg1.txt
# Emails/stop/part4/spmsga87.txt
# Emails/stop/part4/6-762msg1.txt
# Emails/stop/part4/6-300msg1.txt
# Emails/stop/part4/6-778msg2.txt
# Emails/stop/part4/8-1071msg2.txt
# Emails/stop/part4/spmsgb100.txt
# Emails/stop/part4/6-294msg1.txt
# Emails/stop/part4/6-245msg2.txt
# Emails/stop/part4/6-376msg1.txt
# Emails/stop/part4/spmsga91.txt
# Emails/stop/part4/6-275msg1.txt
# Emails/stop/part4/6-273msg2.txt
# Emails/stop/part4/6-289msg2.txt
# Emails/stop/part4/6-364msg1.txt
# Emails/stop/part4/6-311msg1.txt
# Emails/stop/part4/6-329msg1.txt
# Emails/stop/part4/6-353msg1.txt
# Emails/stop/part4/spmsgb109.txt
# Emails/stop/part4/8-1066msg1.txt
# Emails/stop/part4/6-297msg1.txt
# Emails/stop/part4/6-433msg1.txt
# Emails/stop/part4/spmsga95.txt
# Emails/stop/part4/6-295msg1.txt
# Emails/stop/part4/6-422msg2.txt
# Emails/stop/part4/6-432msg1.txt
# Emails/stop/part4/6-468msg2.txt
# Emails/stop/part4/spmsgb103.txt
# Emails/stop/part4/spmsgb108.txt
# Emails/stop/part4/6-266msg2.txt
# Emails/stop/part4/6-378msg3.txt
# Emails/stop/part4/spmsgb117.txt
# Emails/stop/part4/6-846msg1.txt
# Emails/stop/part4/8-1112msg1.txt
# Emails/stop/part4/6-53msg1.txt
# Emails/stop/part4/spmsga85.txt
# Emails/stop/part4/spmsgb102.txt
# Emails/stop/part4/6-267msg1.txt
# Emails/stop/part4/spmsgb120.txt
# Emails/stop/part4/6-843msg3.txt
# Emails/stop/part4/spmsga92.txt
# Emails/stop/part4/6-353msg2.txt
# Emails/stop/part4/6-327msg2.txt
# Emails/stop/part4/6-864msg1.txt
# Emails/stop/part4/6-297msg2.txt
# Emails/stop/part4/6-360msg1.txt
# Emails/stop/part4/6-297msg3.txt
# Emails/stop/part4/6-389msg1.txt
# Emails/stop/part4/6-4msg3.txt
# Emails/stop/part4/6-272msg1.txt
# Emails/stop/part4/6-359msg1.txt
# Emails/stop/part4/spmsgb11.txt
# Emails/stop/part4/6-893msg1.txt
# Emails/stop/part4/6-789msg3.txt
# Emails/stop/part4/6-762msg2.txt
# Emails/stop/part4/6-362msg1.txt
# Emails/stop/part4/6-475msg1.txt
# Emails/stop/part4/6-400msg1.txt
# Emails/stop/part4/8-1087msg1.txt
# Emails/stop/part2/6-1050msg1.txt
# Emails/stop/part2/spmsga149.txt
# Emails/stop/part2/5-1419msg1.txt
# Emails/stop/part2/5-1372msg3.txt
# Emails/stop/part2/5-1388msg1.txt
# Emails/stop/part2/5-1474msg1.txt
# Emails/stop/part2/5-1473msg1.txt
# Emails/stop/part2/5-1353msg3.txt
# Emails/stop/part2/5-1490msg1.txt
# Emails/stop/part2/spmsga21.txt
# Emails/stop/part2/6-1056msg1.txt
# Emails/stop/part2/spmsga143.txt
# Emails/stop/part2/5-1452msg1.txt
# Emails/stop/part2/6-1031msg1.txt
# Emails/stop/part2/5-1459msg2.txt
# Emails/stop/part2/6-1020msg1.txt
# Emails/stop/part2/5-1444msg1.txt
# Emails/stop/part2/5-1455msg1.txt
# Emails/stop/part2/5-1413msg4.txt
# Emails/stop/part2/5-1455msg2.txt
# Emails/stop/part2/spmsga18.txt
# Emails/stop/part2/5-1378msg1.txt
# Emails/stop/part2/5-1384msg1.txt
# Emails/stop/part2/5-1328msg1.txt
# Emails/stop/part2/6-1033msg1.txt
# Emails/stop/part2/spmsga165.txt
# Emails/stop/part2/6-1030msg3.txt
# Emails/stop/part2/6-1055msg1.txt
# Emails/stop/part2/5-1445msg1.txt
# Emails/stop/part2/5-1338msg1.txt
# Emails/stop/part2/5-1405msg3.txt
# Emails/stop/part2/5-1468msg1.txt
# Emails/stop/part2/6-1030msg2.txt
# Emails/stop/part2/5-1498msg1.txt
# Emails/stop/part2/5-1402msg2.txt
# Emails/stop/part2/5-1462msg3.txt
# Emails/stop/part2/5-1390msg3.txt
# Emails/stop/part2/spmsga160.txt
# Emails/stop/part2/spmsga27.txt
# Emails/stop/part2/5-1375msg4.txt
# Emails/stop/part2/spmsga2.txt
# Emails/stop/part2/5-1464msg1.txt
# Emails/stop/part2/5-1311msg3.txt
# Emails/stop/part2/5-1443msg1.txt
# Emails/stop/part2/6-1044msg1.txt
# Emails/stop/part2/5-1375msg1.txt
# Emails/stop/part2/5-1375msg2.txt
# Emails/stop/part2/5-1332msg1.txt
# Emails/stop/part2/5-1302msg1.txt
# Emails/stop/part2/6-1045msg1.txt
# Emails/stop/part2/5-1479msg1.txt
# Emails/stop/part2/spmsga153.txt
# Emails/stop/part2/6-1051msg1.txt
# Emails/stop/part2/spmsga33.txt
# Emails/stop/part2/6-1011msg1.txt
# Emails/stop/part2/5-1482msg2.txt
# Emails/stop/part2/5-1482msg5.txt
# Emails/stop/part2/5-1495msg1.txt
# Emails/stop/part2/spmsga144.txt
# Emails/stop/part2/5-1482msg4.txt
# Emails/stop/part2/5-1372msg2.txt
# Emails/stop/part2/5-1484msg1.txt
# Emails/stop/part2/spmsga30.txt
# Emails/stop/part2/spmsga164.txt
# Emails/stop/part2/5-1482msg3.txt
# Emails/stop/part2/6-1003msg1.txt
# Emails/stop/part2/5-1435msg1.txt
# Emails/stop/part2/5-1488msg3.txt
# Emails/stop/part2/5-1298msg3.txt
# Emails/stop/part2/5-1298msg2.txt
# Emails/stop/part2/spmsga146.txt
# Emails/stop/part2/5-1506msg1.txt
# Emails/stop/part2/5-1377msg1.txt
# Emails/stop/part2/5-1510msg1.txt
# Emails/stop/part2/5-1462msg1.txt
# Emails/stop/part2/spmsga23.txt
# Emails/stop/part2/5-1459msg1.txt
# Emails/stop/part2/5-1435msg3.txt
# Emails/stop/part2/5-1300msg2.txt
# Emails/stop/part2/6-1049msg1.txt
# Emails/stop/part2/5-1505msg1.txt
# Emails/stop/part2/5-1454msg2.txt
# Emails/stop/part2/6-1004msg1.txt
# Emails/stop/part2/5-1307msg2.txt
# Emails/stop/part2/spmsga3.txt
# Emails/stop/part2/5-1307msg3.txt
# Emails/stop/part2/5-1492msg1.txt
# Emails/stop/part2/6-1010msg1.txt
# Emails/stop/part2/6-1037msg3.txt
# Emails/stop/part2/5-1329msg1.txt
# Emails/stop/part2/5-1463msg1.txt
# Emails/stop/part2/6-1036msg1.txt
# Emails/stop/part2/spmsga19.txt
# Emails/stop/part2/5-1442msg1.txt
# Emails/stop/part2/6-1030msg1.txt
# Emails/stop/part2/5-1450msg1.txt
# Emails/stop/part2/5-1491msg1.txt
# Emails/stop/part2/5-1430msg3.txt
# Emails/stop/part2/5-1375msg3.txt
# Emails/stop/part2/5-1453msg3.txt
# Emails/stop/part2/5-1454msg1.txt
# Emails/stop/part2/5-1470msg1.txt
# Emails/stop/part2/5-1496msg3.txt
# Emails/stop/part2/spmsga20.txt
# Emails/stop/part2/5-1300msg3.txt
# Emails/stop/part2/spmsga148.txt
# Emails/stop/part2/5-1453msg1.txt
# Emails/stop/part2/5-1353msg1.txt
# Emails/stop/part2/spmsga166.txt
# Emails/stop/part2/5-1487msg1.txt
# Emails/stop/part2/5-1472msg1.txt
# Emails/stop/part2/5-1356msg1.txt
# Emails/stop/part2/5-1453msg2.txt
# Emails/stop/part2/spmsga147.txt
# Emails/stop/part2/5-1326msg1.txt
# Emails/stop/part2/5-1486msg1.txt
# Emails/stop/part2/spmsga15.txt
# Emails/stop/part2/spmsga161.txt
# Emails/stop/part2/6-1052msg1.txt
# Emails/stop/part2/5-1358msg1.txt
# Emails/stop/part2/5-1496msg1.txt
# Emails/stop/part2/5-1405msg2.txt
# Emails/stop/part2/5-1471msg1.txt
# Emails/stop/part2/5-1359msg1.txt
# Emails/stop/part2/6-1041msg1.txt
# Emails/stop/part2/5-1508msg1.txt
# Emails/stop/part2/5-1416msg1.txt
# Emails/stop/part2/spmsga26.txt
# Emails/stop/part2/6-1000msg1.txt
# Emails/stop/part2/6-1021msg1.txt
# Emails/stop/part2/5-1385msg1.txt
# Emails/stop/part2/spmsga145.txt
# Emails/stop/part2/spmsga24.txt
# Emails/stop/part2/spmsga156.txt
# Emails/stop/part2/5-1430msg2.txt
# Emails/stop/part2/5-1393msg1.txt
# Emails/stop/part2/spmsga29.txt
# Emails/stop/part2/6-1005msg1.txt
# Emails/stop/part2/spmsga25.txt
# Emails/stop/part2/spmsga163.txt
# Emails/stop/part2/spmsga22.txt
# Emails/stop/part2/6-1002msg1.txt
# Emails/stop/part2/5-1386msg1.txt
# Emails/stop/part2/5-1318msg1.txt
# Emails/stop/part2/6-1001msg1.txt
# Emails/stop/part2/spmsga152.txt
# Emails/stop/part2/spmsga158.txt
# Emails/stop/part2/5-1496msg2.txt
# Emails/stop/part2/5-1331msg1.txt
# Emails/stop/part2/5-1488msg2.txt
# Emails/stop/part2/5-1508msg3.txt
# Emails/stop/part2/spmsga17.txt
# Emails/stop/part2/5-1504msg1.txt
# Emails/stop/part2/5-1376msg1.txt
# Emails/stop/part2/spmsga32.txt
# Emails/stop/part2/spmsga16.txt
# Emails/stop/part2/5-1371msg0.txt
# Emails/stop/part2/6-1017msg1.txt
# Emails/stop/part2/5-1488msg1.txt
# Emails/stop/part2/6-1048msg1.txt
# Emails/stop/part2/spmsga162.txt
# Emails/stop/part2/spmsga151.txt
# Emails/stop/part2/5-1303msg3.txt
# Emails/stop/part2/6-1008msg1.txt
# Emails/stop/part2/spmsga154.txt
# Emails/stop/part2/6-1037msg2.txt
# Emails/stop/part2/spmsga155.txt
# Emails/stop/part2/5-1298msg1.txt
# Emails/stop/part2/6-1050msg3.txt
# Emails/stop/part2/5-1344msg1.txt
# Emails/stop/part2/spmsga150.txt
# Emails/stop/part2/5-1455msg3.txt
# Emails/stop/part2/5-1466msg1.txt
# Emails/stop/part2/6-1022msg1.txt
# Emails/stop/part2/6-1025msg1.txt
# Emails/stop/part2/5-1499msg1.txt
# Emails/stop/part2/5-1509msg1.txt
# Emails/stop/part2/6-1032msg1.txt
# Emails/stop/part2/6-1040msg1.txt
# Emails/stop/part2/5-1510msg2.txt
# Emails/stop/part2/5-1482msg1.txt
# Emails/stop/part2/6-1035msg1.txt
# Emails/stop/part2/5-1475msg1.txt
# Emails/stop/part2/6-1009msg1.txt
# Emails/stop/part2/6-1029msg1.txt
# Emails/stop/part2/6-1037msg1.txt
# Emails/stop/part2/spmsga157.txt
# Emails/stop/part2/5-1462msg2.txt
# Emails/stop/part2/5-1420msg3.txt
# Emails/stop/part2/spmsga159.txt
# Emails/stop/part2/5-1460msg1.txt
# Emails/stop/part2/5-1508msg2.txt
# Emails/stop/part2/5-1402msg3.txt
# Emails/stop/part2/5-1315msg2.txt
# Emails/stop/part2/5-1318msg3.txt
# Emails/stop/part2/5-1510msg3.txt
# Emails/stop/part2/6-1047msg1.txt
# Emails/stop/part2/6-1039msg1.txt
# Emails/stop/part2/spmsga28.txt
# Emails/stop/part2/5-1353msg2.txt
# Emails/stop/part2/5-1390msg1.txt
# Emails/stop/part2/5-1458msg1.txt
# Emails/stop/part2/spmsga35.txt
# Emails/stop/part2/spmsga142.txt
# Emails/stop/part2/5-1497msg1.txt
# Emails/stop/part2/6-1013msg1.txt
# Emails/stop/part2/5-1440msg1.txt
# Emails/stop/part2/6-1036msg2.txt
# Emails/stop/part2/5-1303msg2.txt
# Emails/stop/part2/6-1018msg1.txt
# Emails/stop/part2/5-1511msg1.txt
# Emails/stop/part2/5-1459msg3.txt
# Emails/stop/part2/6-1019msg1.txt
# Emails/stop/part2/6-1036msg3.txt
# Emails/stop/part2/6-1050msg2.txt
# Emails/stop/part2/spmsga34.txt
# Emails/stop/part2/5-1301msg1.txt
# Emails/stop/part2/5-1503msg1.txt
# Emails/stop/part2/spmsga31.txt
# Emails/stop/part10/spmsgc87.txt
# Emails/stop/part10/9-874msg1.txt
# Emails/stop/part10/spmsgc85.txt
# Emails/stop/part10/9-62msg1.txt
# Emails/stop/part10/9-843msg1.txt
# Emails/stop/part10/9-83msg2.txt
# Emails/stop/part10/9-960msg1.txt
# Emails/stop/part10/spmsgc96.txt
# Emails/stop/part10/spmsgc81.txt
# Emails/stop/part10/9-948msg1.txt
# Emails/stop/part10/9-654msg1.txt
# Emails/stop/part10/9-863msg1.txt
# Emails/stop/part10/spmsgc71.txt
# Emails/stop/part10/9-629msg1.txt
# Emails/stop/part10/9-628msg2.txt
# Emails/stop/part10/9-633msg1.txt
# Emails/stop/part10/9-893msg2.txt
# Emails/stop/part10/9-973msg1.txt
# Emails/stop/part10/9-922msg1.txt
# Emails/stop/part10/9-882msg1.txt
# Emails/stop/part10/9-723msg1.txt
# Emails/stop/part10/9-778msg1.txt
# Emails/stop/part10/9-744msg1.txt
# Emails/stop/part10/spmsgc68.txt
# Emails/stop/part10/9-78msg1.txt
# Emails/stop/part10/9-771msg2.txt
# Emails/stop/part10/9-655msg1.txt
# Emails/stop/part10/spmsgc72.txt
# Emails/stop/part10/9-656msg1.txt
# Emails/stop/part10/9-643msg1.txt
# Emails/stop/part10/9-901msg1.txt
# Emails/stop/part10/9-838msg1.txt
# Emails/stop/part10/spmsgc58.txt
# Emails/stop/part10/9-660msg2.txt
# Emails/stop/part10/spmsgc82.txt
# Emails/stop/part10/9-761msg1.txt
# Emails/stop/part10/spmsgc69.txt
# Emails/stop/part10/9-87msg1.txt
# Emails/stop/part10/9-780msg1.txt
# Emails/stop/part10/9-736msg1.txt
# Emails/stop/part10/9-736msg2.txt
# Emails/stop/part10/9-833msg2.txt
# Emails/stop/part10/spmsgc76.txt
# Emails/stop/part10/spmsgc94.txt
# Emails/stop/part10/9-989msg1.txt
# Emails/stop/part10/9-628msg1.txt
# Emails/stop/part10/9-893msg1.txt
# Emails/stop/part10/9-883msg1.txt
# Emails/stop/part10/9-66msg1.txt
# Emails/stop/part10/9-645msg1.txt
# Emails/stop/part10/9-751msg1.txt
# Emails/stop/part10/spmsgc57.txt
# Emails/stop/part10/9-870msg1.txt
# Emails/stop/part10/spmsgc70.txt
# Emails/stop/part10/9-836msg1.txt
# Emails/stop/part10/9-886msg1.txt
# Emails/stop/part10/9-966msg1.txt
# Emails/stop/part10/spmsgc64.txt
# Emails/stop/part10/spmsgc92.txt
# Emails/stop/part10/9-606msg1.txt
# Emails/stop/part10/9-643msg2.txt
# Emails/stop/part10/9-678msg1.txt
# Emails/stop/part10/9-781msg1.txt
# Emails/stop/part10/9-72msg2.txt
# Emails/stop/part10/9-787msg1.txt
# Emails/stop/part10/9-78msg2.txt
# Emails/stop/part10/spmsgc61.txt
# Emails/stop/part10/spmsgc95.txt
# Emails/stop/part10/9-996msg1.txt
# Emails/stop/part10/9-842msg1.txt
# Emails/stop/part10/9-884msg1.txt
# Emails/stop/part10/9-86msg2.txt
# Emails/stop/part10/9-878msg1.txt
# Emails/stop/part10/9-74msg2.txt
# Emails/stop/part10/9-663msg1.txt
# Emails/stop/part10/9-818msg1.txt
# Emails/stop/part10/spmsgc86.txt
# Emails/stop/part10/9-652msg2.txt
# Emails/stop/part10/9-678msg2.txt
# Emails/stop/part10/9-967msg1.txt
# Emails/stop/part10/9-892msg2.txt
# Emails/stop/part10/9-907msg1.txt
# Emails/stop/part10/9-608msg1.txt
# Emails/stop/part10/9-969msg2.txt
# Emails/stop/part10/9-5msg2.txt
# Emails/stop/part10/9-832msg2.txt
# Emails/stop/part10/9-613msg1.txt
# Emails/stop/part10/spmsgc60.txt
# Emails/stop/part10/9-920msg1.txt
# Emails/stop/part10/spmsgc6.txt
# Emails/stop/part10/spmsgc97.txt
# Emails/stop/part10/9-847msg1.txt
# Emails/stop/part10/9-709msg1.txt
# Emails/stop/part10/9-969msg1.txt
# Emails/stop/part10/9-717msg2.txt
# Emails/stop/part10/spmsgc88.txt
# Emails/stop/part10/9-841msg1.txt
# Emails/stop/part10/9-652msg1.txt
# Emails/stop/part10/spmsgc83.txt
# Emails/stop/part10/9-98msg1.txt
# Emails/stop/part10/9-745msg1.txt
# Emails/stop/part10/9-983msg2.txt
# Emails/stop/part10/spmsgc66.txt
# Emails/stop/part10/9-824msg1.txt
# Emails/stop/part10/spmsgc75.txt
# Emails/stop/part10/9-719msg1.txt
# Emails/stop/part10/9-88msg2.txt
# Emails/stop/part10/9-957msg1.txt
# Emails/stop/part10/9-742msg1.txt
# Emails/stop/part10/9-865msg1.txt
# Emails/stop/part10/9-749msg1.txt
# Emails/stop/part10/9-697msg2.txt
# Emails/stop/part10/9-640msg1.txt
# Emails/stop/part10/9-881msg1.txt
# Emails/stop/part10/9-74msg1.txt
# Emails/stop/part10/9-708msg1.txt
# Emails/stop/part10/9-692msg1.txt
# Emails/stop/part10/spmsgc91.txt
# Emails/stop/part10/9-835msg2.txt
# Emails/stop/part10/9-839msg1.txt
# Emails/stop/part10/9-884msg2.txt
# Emails/stop/part10/9-722msg1.txt
# Emails/stop/part10/9-607msg1.txt
# Emails/stop/part10/9-731msg1.txt
# Emails/stop/part10/9-852msg1.txt
# Emails/stop/part10/9-637msg1.txt
# Emails/stop/part10/9-832msg1.txt
# Emails/stop/part10/9-746msg1.txt
# Emails/stop/part10/9-864msg2.txt
# Emails/stop/part10/9-902msg1.txt
# Emails/stop/part10/9-971msg1.txt
# Emails/stop/part10/spmsgc99.txt
# Emails/stop/part10/9-981msg1.txt
# Emails/stop/part10/9-837msg1.txt
# Emails/stop/part10/9-627msg1.txt
# Emails/stop/part10/9-694msg1.txt
# Emails/stop/part10/9-864msg1.txt
# Emails/stop/part10/9-597msg2.txt
# Emails/stop/part10/9-877msg1.txt
# Emails/stop/part10/9-650msg2.txt
# Emails/stop/part10/spmsgc55.txt
# Emails/stop/part10/9-608msg2.txt
# Emails/stop/part10/9-83msg1.txt
# Emails/stop/part10/9-634msg2.txt
# Emails/stop/part10/spmsgc80.txt
# Emails/stop/part10/9-915msg1.txt
# Emails/stop/part10/9-779msg1.txt
# Emails/stop/part10/spmsgc93.txt
# Emails/stop/part10/9-707msg1.txt
# Emails/stop/part10/9-88msg1.txt
# Emails/stop/part10/9-597msg1.txt
# Emails/stop/part10/spmsgc7.txt
# Emails/stop/part10/spmsgc84.txt
# Emails/stop/part10/spmsgc90.txt
# Emails/stop/part10/9-6msg1.txt
# Emails/stop/part10/9-627msg2.txt
# Emails/stop/part10/9-986msg1.txt
# Emails/stop/part10/9-974msg1.txt
# Emails/stop/part10/9-997msg1.txt
# Emails/stop/part10/9-792msg2.txt
# Emails/stop/part10/spmsgc56.txt
# Emails/stop/part10/9-958msg1.txt
# Emails/stop/part10/9-630msg2.txt
# Emails/stop/part10/9-862msg1.txt
# Emails/stop/part10/9-684msg1.txt
# Emails/stop/part10/9-983msg1.txt
# Emails/stop/part10/spmsgc65.txt
# Emails/stop/part10/9-802msg1.txt
# Emails/stop/part10/spmsgc77.txt
# Emails/stop/part10/9-916msg1.txt
# Emails/stop/part10/9-955msg1.txt
# Emails/stop/part10/9-817msg1.txt
# Emails/stop/part10/9-6msg2.txt
# Emails/stop/part10/spmsgc67.txt
# Emails/stop/part10/9-792msg1.txt
# Emails/stop/part10/spmsgc73.txt
# Emails/stop/part10/9-907msg2.txt
# Emails/stop/part10/9-984msg2.txt
# Emails/stop/part10/spmsgc79.txt
# Emails/stop/part10/9-607msg2.txt
# Emails/stop/part10/9-715msg1.txt
# Emails/stop/part10/9-64msg2.txt
# Emails/stop/part10/9-72msg1.txt
# Emails/stop/part10/spmsgc78.txt
# Emails/stop/part10/9-59msg1.txt
# Emails/stop/part10/9-816msg1.txt
# Emails/stop/part10/9-941msg1.txt
# Emails/stop/part10/9-653msg1.txt
# Emails/stop/part10/9-718msg1.txt
# Emails/stop/part10/spmsgc63.txt
# Emails/stop/part10/spmsgc62.txt
# Emails/stop/part10/9-939msg1.txt
# Emails/stop/part10/9-869msg1.txt
# Emails/stop/part10/9-79msg1.txt
# Emails/stop/part10/9-857msg1.txt
# Emails/stop/part10/9-734msg1.txt
# Emails/stop/part10/9-637msg2.txt
# Emails/stop/part10/9-944msg1.txt
# Emails/stop/part10/9-86msg1.txt
# Emails/stop/part10/spmsgc59.txt
# Emails/stop/part10/9-968msg1.txt
# Emails/stop/part10/9-634msg1.txt
# Emails/stop/part10/9-961msg1.txt
# Emails/stop/part10/9-612msg1.txt
# Emails/stop/part10/9-695msg1.txt
# Emails/stop/part10/9-625msg1.txt
# Emails/stop/part10/9-887msg1.txt
# Emails/stop/part10/9-64msg1.txt
# Emails/stop/part10/9-931msg1.txt
# Emails/stop/part10/spmsgc9.txt
# Emails/stop/part10/spmsgc89.txt
# Emails/stop/part10/spmsgc74.txt
# Emails/stop/part10/spmsgc8.txt
# Emails/stop/part10/9-942msg1.txt
# Emails/stop/part10/9-621msg1.txt
# Emails/stop/part10/9-858msg1.txt
# Emails/stop/part10/9-63msg1.txt
# Emails/stop/part10/9-705msg1.txt
# Emails/stop/part10/9-650msg1.txt
# Emails/stop/part10/spmsgc98.txt
# Emails/stop/part8/6-80msg5.txt
# Emails/stop/part8/6-878msg1.txt
# Emails/stop/part8/6-891msg1.txt
# Emails/stop/part8/8-1171msg1.txt
# Emails/stop/part8/6-939msg2.txt
# Emails/stop/part8/8-1110msg1.txt
# Emails/stop/part8/6-839msg2.txt
# Emails/stop/part8/6-896msg2.txt
# Emails/stop/part8/8-1229msg1.txt
# Emails/stop/part8/6-948msg1.txt
# Emails/stop/part8/6-825msg2.txt
# Emails/stop/part8/8-1084msg1.txt
# Emails/stop/part8/8-1119msg1.txt
# Emails/stop/part8/spmsgc11.txt
# Emails/stop/part8/spmsgc105.txt
# Emails/stop/part8/8-1084msg2.txt
# Emails/stop/part8/6-900msg1.txt
# Emails/stop/part8/8-1216msg1.txt
# Emails/stop/part8/6-80msg3.txt
# Emails/stop/part8/6-828msg1.txt
# Emails/stop/part8/8-1030msg1.txt
# Emails/stop/part8/spmsgc113.txt
# Emails/stop/part8/6-809msg1.txt
# Emails/stop/part8/6-890msg1.txt
# Emails/stop/part8/6-833msg1.txt
# Emails/stop/part8/6-955msg2.txt
# Emails/stop/part8/6-955msg1.txt
# Emails/stop/part8/8-1247msg1.txt
# Emails/stop/part8/8-1092msg1.txt
# Emails/stop/part8/spmsgc136.txt
# Emails/stop/part8/6-916msg2.txt
# Emails/stop/part8/6-915msg1.txt
# Emails/stop/part8/8-1168msg1.txt
# Emails/stop/part8/6-987msg2.txt
# Emails/stop/part8/8-1202msg1.txt
# Emails/stop/part8/6-921msg3.txt
# Emails/stop/part8/6-943msg1.txt
# Emails/stop/part8/spmsgc125.txt
# Emails/stop/part8/8-1153msg3.txt
# Emails/stop/part8/8-1113msg1.txt
# Emails/stop/part8/6-990msg1.txt
# Emails/stop/part8/8-1082msg1.txt
# Emails/stop/part8/spmsgc140.txt
# Emails/stop/part8/6-80msg1.txt
# Emails/stop/part8/8-1206msg2.txt
# Emails/stop/part8/6-856msg3.txt
# Emails/stop/part8/6-987msg4.txt
# Emails/stop/part8/6-856msg2.txt
# Emails/stop/part8/6-7msg1.txt
# Emails/stop/part8/spmsgc107.txt
# Emails/stop/part8/6-823msg1.txt
# Emails/stop/part8/8-1064msg1.txt
# Emails/stop/part8/8-1185msg1.txt
# Emails/stop/part8/6-818msg1.txt
# Emails/stop/part8/8-1096msg1.txt
# Emails/stop/part8/spmsgc14.txt
# Emails/stop/part8/6-839msg3.txt
# Emails/stop/part8/8-1000msg1.txt
# Emails/stop/part8/8-1137msg1.txt
# Emails/stop/part8/6-7msg2.txt
# Emails/stop/part8/6-875msg3.txt
# Emails/stop/part8/8-1232msg1.txt
# Emails/stop/part8/6-875msg1.txt
# Emails/stop/part8/6-977msg1.txt
# Emails/stop/part8/6-992msg3.txt
# Emails/stop/part8/spmsgc127.txt
# Emails/stop/part8/8-1077msg1.txt
# Emails/stop/part8/6-949msg2.txt
# Emails/stop/part8/8-1232msg3.txt
# Emails/stop/part8/8-1232msg2.txt
# Emails/stop/part8/6-852msg1.txt
# Emails/stop/part8/6-890msg3.txt
# Emails/stop/part8/6-813msg1.txt
# Emails/stop/part8/8-1126msg1.txt
# Emails/stop/part8/6-916msg3.txt
# Emails/stop/part8/6-922msg2.txt
# Emails/stop/part8/6-938msg1.txt
# Emails/stop/part8/6-957msg1.txt
# Emails/stop/part8/6-806msg1.txt
# Emails/stop/part8/6-96msg1.txt
# Emails/stop/part8/6-875msg2.txt
# Emails/stop/part8/6-841msg1.txt
# Emails/stop/part8/6-921msg2.txt
# Emails/stop/part8/6-993msg1.txt
# Emails/stop/part8/8-1057msg1.txt
# Emails/stop/part8/6-890msg2.txt
# Emails/stop/part8/6-923msg1.txt
# Emails/stop/part8/8-1226msg1.txt
# Emails/stop/part8/6-825msg1.txt
# Emails/stop/part8/8-1212msg1.txt
# Emails/stop/part8/6-965msg1.txt
# Emails/stop/part8/6-983msg1.txt
# Emails/stop/part8/6-829msg1.txt
# Emails/stop/part8/6-992msg5.txt
# Emails/stop/part8/8-1020msg1.txt
# Emails/stop/part8/6-809msg3.txt
# Emails/stop/part8/spmsgc129.txt
# Emails/stop/part8/spmsgc138.txt
# Emails/stop/part8/6-839msg1.txt
# Emails/stop/part8/spmsgc103.txt
# Emails/stop/part8/8-816msg1.txt
# Emails/stop/part8/8-1075msg1.txt
# Emails/stop/part8/6-987msg1.txt
# Emails/stop/part8/8-1225msg1.txt
# Emails/stop/part8/6-828msg3.txt
# Emails/stop/part8/6-951msg1.txt
# Emails/stop/part8/8-1173msg1.txt
# Emails/stop/part8/6-89msg1.txt
# Emails/stop/part8/8-1122msg1.txt
# Emails/stop/part8/8-1054msg1.txt
# Emails/stop/part8/6-802msg2.txt
# Emails/stop/part8/spmsgc116.txt
# Emails/stop/part8/6-904msg0.txt
# Emails/stop/part8/6-82msg1.txt
# Emails/stop/part8/6-879msg1.txt
# Emails/stop/part8/8-1201msg1.txt
# Emails/stop/part8/6-838msg1.txt
# Emails/stop/part8/spmsgc109.txt
# Emails/stop/part8/8-1139msg1.txt
# Emails/stop/part8/8-1117msg1.txt
# Emails/stop/part8/6-802msg1.txt
# Emails/stop/part8/spmsgc102.txt
# Emails/stop/part8/6-992msg4.txt
# Emails/stop/part8/6-813msg3.txt
# Emails/stop/part8/6-832msg1.txt
# Emails/stop/part8/8-1153msg2.txt
# Emails/stop/part8/6-995msg1.txt
# Emails/stop/part8/spmsgc118.txt
# Emails/stop/part8/6-80msg2.txt
# Emails/stop/part8/6-957msg2.txt
# Emails/stop/part8/6-987msg3.txt
# Emails/stop/part8/6-957msg4.txt
# Emails/stop/part8/6-816msg1.txt
# Emails/stop/part8/6-914msg1.txt
# Emails/stop/part8/spmsgc122.txt
# Emails/stop/part8/6-897msg1.txt
# Emails/stop/part8/6-825msg3.txt
# Emails/stop/part8/6-981msg2.txt
# Emails/stop/part8/6-802msg0.txt
# Emails/stop/part8/8-1125msg2.txt
# Emails/stop/part8/spmsgc128.txt
# Emails/stop/part8/6-844msg3.txt
# Emails/stop/part8/6-907msg2.txt
# Emails/stop/part8/6-801msg3.txt
# Emails/stop/part8/6-957msg3.txt
# Emails/stop/part8/6-820msg1.txt
# Emails/stop/part8/8-1018msg1.txt
# Emails/stop/part8/8-1179msg1.txt
# Emails/stop/part8/6-916msg1.txt
# Emails/stop/part8/spmsgc123.txt
# Emails/stop/part8/8-1144msg1.txt
# Emails/stop/part8/8-1001msg1.txt
# Emails/stop/part8/8-1086msg1.txt
# Emails/stop/part8/6-806msg3.txt
# Emails/stop/part8/8-1225msg4.txt
# Emails/stop/part8/8-1232msg4.txt
# Emails/stop/part8/8-1132msg1.txt
# Emails/stop/part8/6-922msg3.txt
# Emails/stop/part8/spmsgc101.txt
# Emails/stop/part8/8-1206msg1.txt
# Emails/stop/part8/6-992msg1.txt
# Emails/stop/part8/6-917msg3.txt
# Emails/stop/part8/8-1041msg1.txt
# Emails/stop/part8/6-828msg2.txt
# Emails/stop/part8/spmsgc108.txt
# Emails/stop/part8/8-1095msg1.txt
# Emails/stop/part8/spmsgc133.txt
# Emails/stop/part8/6-830msg1.txt
# Emails/stop/part8/6-955msg3.txt
# Emails/stop/part8/6-957msg5.txt
# Emails/stop/part8/6-877msg1.txt
# Emails/stop/part8/spmsgc111.txt
# Emails/stop/part8/8-1206msg3.txt
# Emails/stop/part8/8-1199msg1.txt
# Emails/stop/part8/8-1108msg1.txt
# Emails/stop/part8/6-989msg1.txt
# Emails/stop/part8/6-917msg1.txt
# Emails/stop/part8/6-907msg3.txt
# Emails/stop/part8/6-845msg1.txt
# Emails/stop/part8/6-949msg1.txt
# Emails/stop/part8/spmsgc131.txt
# Emails/stop/part8/6-917msg2.txt
# Emails/stop/part8/8-1171msg2.txt
# Emails/stop/part8/6-837msg1.txt
# Emails/stop/part8/8-1150msg1.txt
# Emails/stop/part8/8-1151msg1.txt
# Emails/stop/part8/6-889msg1.txt
# Emails/stop/part8/6-896msg1.txt
# Emails/stop/part8/8-1177msg1.txt
# Emails/stop/part8/8-1044msg1.txt
# Emails/stop/part8/8-1017msg1.txt
# Emails/stop/part8/8-1243msg1.txt
# Emails/stop/part8/6-856msg1.txt
# Emails/stop/part8/6-921msg1.txt
# Emails/stop/part8/8-1079msg1.txt
# Emails/stop/part8/6-904msg1.txt
# Emails/stop/part8/spmsgc114.txt
# Emails/stop/part8/8-1154msg1.txt
# Emails/stop/part8/6-829msg2.txt
# Emails/stop/part8/spmsgc100.txt
# Emails/stop/part8/8-1031msg1.txt
# Emails/stop/part8/6-922msg1.txt
# Emails/stop/part8/6-799msg1.txt
# Emails/stop/part8/8-1075msg2.txt
# Emails/stop/part8/8-1051msg1.txt
# Emails/stop/part8/6-7msg3.txt
# Emails/stop/part8/spmsgc139.txt
# Emails/stop/part8/6-896msg3.txt
# Emails/stop/part8/8-1097msg1.txt
# Emails/stop/part8/6-978msg1.txt
# Emails/stop/part8/6-809msg2.txt
# Emails/stop/part8/spmsgc119.txt
# Emails/stop/part8/6-819msg1.txt
# Emails/stop/part8/6-907msg1.txt
# Emails/stop/part8/spmsgc120.txt
# Emails/stop/part8/8-1134msg1.txt
# Emails/stop/part8/6-806msg2.txt
# Emails/stop/part8/8-1125msg1.txt
# Emails/stop/part8/6-953msg1.txt
# Emails/stop/part8/6-831msg1.txt
# Emails/stop/part8/6-854msg1.txt
# Emails/stop/part8/spmsgc137.txt
# Emails/stop/part8/spmsgc117.txt
# Emails/stop/part8/8-1136msg1.txt
# Emails/stop/part8/8-1125msg3.txt
# Emails/stop/part8/6-981msg3.txt
# Emails/stop/part8/8-1104msg1.txt
# Emails/stop/part8/spmsgc135.txt
# Emails/stop/part8/8-1123msg1.txt
# Emails/stop/part8/8-1221msg1.txt
# Emails/stop/part8/spmsgc13.txt
# Emails/stop/part8/6-992msg2.txt
# Emails/stop/part8/6-80msg4.txt
# Emails/stop/part8/6-801msg1.txt
# Emails/stop/part8/6-897msg2.txt
# Emails/stop/part8/spmsgc110.txt
# Emails/stop/part8/6-939msg3.txt
# Emails/stop/part8/8-1153msg1.txt
# Emails/stop/part8/8-1207msg1.txt
# Emails/stop/part8/6-801msg2.txt
# Emails/stop/part8/spmsgc12.txt
# Emails/stop/part8/8-1125msg4.txt
# Emails/stop/part8/8-1089msg1.txt
# Emails/stop/part8/8-1163msg1.txt
# Emails/stop/part8/8-1133msg1.txt
# Emails/stop/part8/spmsgc121.txt
# Emails/stop/part8/6-813msg2.txt
# Emails/stop/part8/8-1135msg1.txt
# Emails/stop/part8/6-981msg1.txt
# Emails/stop/part8/6-939msg1.txt
# Emails/stop/part8/6-985msg1.txt
# Emails/stop/part8/6-829msg3.txt
# Emails/stop/part8/8-1171msg3.txt
# Emails/stop/part8/spmsgc126.txt
# Emails/stop/part8/6-823msg2.txt
# Emails/stop/part8/8-1178msg1.txt
# Emails/stop/part8/spmsgc124.txt
# Emails/stop/part8/8-1225msg2.txt
# Emails/stop/part8/8-1152msg1.txt
# Emails/stop/part8/spmsgc142.txt
# Emails/stop/part8/spmsgc134.txt
# Emails/stop/part8/6-959msg1.txt
# Emails/stop/part8/8-1128msg1.txt
# Emails/stop/part8/6-798msg3.txt
# Emails/stop/part8/6-987msg5.txt
# Emails/stop/part8/8-1237msg1.txt
# Emails/stop/part8/spmsgc115.txt
# Emails/stop/part8/spmsgc130.txt
# Emails/stop/part8/spmsgc141.txt
# Emails/stop/part8/spmsgc106.txt
# Emails/stop/part8/8-1208msg1.txt
# Emails/stop/part8/8-1220msg1.txt
# Emails/stop/part8/6-97msg1.txt
# Emails/stop/part8/spmsgc112.txt
# Emails/stop/part8/spmsgc143.txt
# Emails/stop/part8/6-897msg3.txt
# Emails/stop/part8/6-964msg1.txt
# Emails/stop/part8/8-810msg1.txt
# Emails/stop/part8/8-1190msg1.txt
# Emails/stop/part8/6-932msg1.txt
# Emails/stop/part8/spmsgc132.txt
# Emails/stop/part8/6-949msg3.txt
# Emails/stop/part8/6-960msg1.txt
# Emails/stop/part8/8-1225msg3.txt
# Emails/stop/part8/8-1222msg1.txt
# Emails/stop/part8/6-855msg1.txt
# Emails/stop/part8/6-941msg1.txt
# Emails/stop/part8/6-976msg1.txt
# Emails/stop/part8/spmsgc104.txt
# Emails/stop/part9/9-429msg1.txt
# Emails/stop/part9/9-542msg1.txt
# Emails/stop/part9/9-4msg2.txt
# Emails/stop/part9/9-530msg1.txt
# Emails/stop/part9/spmsgc15.txt
# Emails/stop/part9/9-36msg2.txt
# Emails/stop/part9/9-387msg1.txt
# Emails/stop/part9/9-463msg2.txt
# Emails/stop/part9/spmsgc54.txt
# Emails/stop/part9/9-339msg1.txt
# Emails/stop/part9/9-578msg1.txt
# Emails/stop/part9/9-590msg2.txt
# Emails/stop/part9/9-404msg1.txt
# Emails/stop/part9/spmsgc49.txt
# Emails/stop/part9/spmsgc50.txt
# Emails/stop/part9/spmsgc37.txt
# Emails/stop/part9/9-220msg1.txt
# Emails/stop/part9/spmsgc38.txt
# Emails/stop/part9/9-289msg1.txt
# Emails/stop/part9/9-475msg2.txt
# Emails/stop/part9/spmsgc17.txt
# Emails/stop/part9/9-505msg2.txt
# Emails/stop/part9/9-420msg1.txt
# Emails/stop/part9/9-38msg1.txt
# Emails/stop/part9/8-956msg1.txt
# Emails/stop/part9/9-554msg1.txt
# Emails/stop/part9/9-442msg2.txt
# Emails/stop/part9/spmsgc28.txt
# Emails/stop/part9/9-465msg1.txt
# Emails/stop/part9/9-527msg1.txt
# Emails/stop/part9/9-56msg2.txt
# Emails/stop/part9/9-579msg1.txt
# Emails/stop/part9/9-526msg1.txt
# Emails/stop/part9/9-316msg1.txt
# Emails/stop/part9/9-437msg2.txt
# Emails/stop/part9/8-978msg1.txt
# Emails/stop/part9/9-25msg1.txt
# Emails/stop/part9/9-524msg1.txt
# Emails/stop/part9/9-414msg1.txt
# Emails/stop/part9/9-185msg1.txt
# Emails/stop/part9/8-879msg1.txt
# Emails/stop/part9/9-436msg1.txt
# Emails/stop/part9/8-828msg4.txt
# Emails/stop/part9/8-878msg1.txt
# Emails/stop/part9/spmsgc146.txt
# Emails/stop/part9/9-391msg1.txt
# Emails/stop/part9/spmsgc3.txt
# Emails/stop/part9/9-479msg1.txt
# Emails/stop/part9/spmsgc4.txt
# Emails/stop/part9/9-435msg2.txt
# Emails/stop/part9/9-488msg1.txt
# Emails/stop/part9/9-536msg1.txt
# Emails/stop/part9/9-551msg1.txt
# Emails/stop/part9/8-930msg1.txt
# Emails/stop/part9/9-41msg2.txt
# Emails/stop/part9/9-552msg2.txt
# Emails/stop/part9/8-844msg1.txt
# Emails/stop/part9/9-53msg2.txt
# Emails/stop/part9/9-491msg1.txt
# Emails/stop/part9/9-53msg1.txt
# Emails/stop/part9/9-376msg2.txt
# Emails/stop/part9/9-535msg1.txt
# Emails/stop/part9/spmsgc27.txt
# Emails/stop/part9/8-826msg1.txt
# Emails/stop/part9/8-933msg2.txt
# Emails/stop/part9/spmsgc46.txt
# Emails/stop/part9/9-572msg1.txt
# Emails/stop/part9/9-590msg1.txt
# Emails/stop/part9/9-496msg1.txt
# Emails/stop/part9/9-1818msg1.txt
# Emails/stop/part9/spmsgc23.txt
# Emails/stop/part9/9-54msg1.txt
# Emails/stop/part9/9-524msg2.txt
# Emails/stop/part9/spmsgc5.txt
# Emails/stop/part9/9-512msg1.txt
# Emails/stop/part9/9-378msg1.txt
# Emails/stop/part9/9-369msg1.txt
# Emails/stop/part9/9-475msg1.txt
# Emails/stop/part9/9-506msg1.txt
# Emails/stop/part9/8-817msg1.txt
# Emails/stop/part9/8-867msg1.txt
# Emails/stop/part9/spmsgc48.txt
# Emails/stop/part9/9-515msg1.txt
# Emails/stop/part9/9-563msg2.txt
# Emails/stop/part9/9-550msg1.txt
# Emails/stop/part9/9-498msg1.txt
# Emails/stop/part9/9-580msg1.txt
# Emails/stop/part9/9-376msg1.txt
# Emails/stop/part9/spmsgc41.txt
# Emails/stop/part9/9-392msg1.txt
# Emails/stop/part9/9-595msg1.txt
# Emails/stop/part9/spmsgc34.txt
# Emails/stop/part9/9-372msg1.txt
# Emails/stop/part9/9-532msg1.txt
# Emails/stop/part9/9-1782msg1.txt
# Emails/stop/part9/8-817msg3.txt
# Emails/stop/part9/9-516msg1.txt
# Emails/stop/part9/9-523msg2.txt
# Emails/stop/part9/8-933msg1.txt
# Emails/stop/part9/spmsgc2.txt
# Emails/stop/part9/spmsgc47.txt
# Emails/stop/part9/9-358msg1.txt
# Emails/stop/part9/spmsgc25.txt
# Emails/stop/part9/9-531msg1.txt
# Emails/stop/part9/9-370msg1.txt
# Emails/stop/part9/8-828msg1.txt
# Emails/stop/part9/9-57msg1.txt
# Emails/stop/part9/9-514msg1.txt
# Emails/stop/part9/9-39msg1.txt
# Emails/stop/part9/8-937msg1.txt
# Emails/stop/part9/9-4msg1.txt
# Emails/stop/part9/9-570msg2.txt
# Emails/stop/part9/8-977msg1.txt
# Emails/stop/part9/9-428msg1.txt
# Emails/stop/part9/9-435msg1.txt
# Emails/stop/part9/9-508msg1.txt
# Emails/stop/part9/9-357msg1.txt
# Emails/stop/part9/spmsgc144.txt
# Emails/stop/part9/9-563msg1.txt
# Emails/stop/part9/8-933msg3.txt
# Emails/stop/part9/9-560msg1.txt
# Emails/stop/part9/9-387msg2.txt
# Emails/stop/part9/9-474msg1.txt
# Emails/stop/part9/9-506msg2.txt
# Emails/stop/part9/8-890msg1.txt
# Emails/stop/part9/9-539msg2.txt
# Emails/stop/part9/8-821msg1.txt
# Emails/stop/part9/spmsgc31.txt
# Emails/stop/part9/8-881msg1.txt
# Emails/stop/part9/8-864msg1.txt
# Emails/stop/part9/8-912msg1.txt
# Emails/stop/part9/9-494msg1.txt
# Emails/stop/part9/spmsgc22.txt
# Emails/stop/part9/9-419msg1.txt
# Emails/stop/part9/8-922msg3.txt
# Emails/stop/part9/8-922msg1.txt
# Emails/stop/part9/9-578msg2.txt
# Emails/stop/part9/9-349msg1.txt
# Emails/stop/part9/9-518msg1.txt
# Emails/stop/part9/9-583msg1.txt
# Emails/stop/part9/spmsgc29.txt
# Emails/stop/part9/9-417msg1.txt
# Emails/stop/part9/9-390msg1.txt
# Emails/stop/part9/8-936msg1.txt
# Emails/stop/part9/9-182msg1.txt
# Emails/stop/part9/9-503msg2.txt
# Emails/stop/part9/spmsgc20.txt
# Emails/stop/part9/spmsgc21.txt
# Emails/stop/part9/8-990msg1.txt
# Emails/stop/part9/8-863msg1.txt
# Emails/stop/part9/spmsgc147.txt
# Emails/stop/part9/8-884msg1.txt
# Emails/stop/part9/9-416msg1.txt
# Emails/stop/part9/9-561msg1.txt
# Emails/stop/part9/9-384msg1.txt
# Emails/stop/part9/9-476msg1.txt
# Emails/stop/part9/spmsgc43.txt
# Emails/stop/part9/9-539msg1.txt
# Emails/stop/part9/9-586msg1.txt
# Emails/stop/part9/9-377msg1.txt
# Emails/stop/part9/9-523msg1.txt
# Emails/stop/part9/9-426msg1.txt
# Emails/stop/part9/9-505msg1.txt
# Emails/stop/part9/spmsgc36.txt
# Emails/stop/part9/9-379msg1.txt
# Emails/stop/part9/9-350msg1.txt
# Emails/stop/part9/8-922msg2.txt
# Emails/stop/part9/8-828msg3.txt
# Emails/stop/part9/9-513msg2.txt
# Emails/stop/part9/9-466msg1.txt
# Emails/stop/part9/8-964msg1.txt
# Emails/stop/part9/9-55msg1.txt
# Emails/stop/part9/9-463msg1.txt
# Emails/stop/part9/9-478msg1.txt
# Emails/stop/part9/9-508msg2.txt
# Emails/stop/part9/9-427msg1.txt
# Emails/stop/part9/8-836msg1.txt
# Emails/stop/part9/8-859msg1.txt
# Emails/stop/part9/9-566msg1.txt
# Emails/stop/part9/9-422msg2.txt
# Emails/stop/part9/9-450msg1.txt
# Emails/stop/part9/9-235msg1.txt
# Emails/stop/part9/9-23msg1.txt
# Emails/stop/part9/9-56msg1.txt
# Emails/stop/part9/spmsgc44.txt
# Emails/stop/part9/8-874msg1.txt
# Emails/stop/part9/spmsgc40.txt
# Emails/stop/part9/9-503msg1.txt
# Emails/stop/part9/9-496msg2.txt
# Emails/stop/part9/spmsgc33.txt
# Emails/stop/part9/spmsgc18.txt
# Emails/stop/part9/8-988msg1.txt
# Emails/stop/part9/9-290msg1.txt
# Emails/stop/part9/8-829msg1.txt
# Emails/stop/part9/9-422msg1.txt
# Emails/stop/part9/9-519msg2.txt
# Emails/stop/part9/9-314msg1.txt
# Emails/stop/part9/9-477msg1.txt
# Emails/stop/part9/9-555msg1.txt
# Emails/stop/part9/spmsgc35.txt
# Emails/stop/part9/9-570msg1.txt
# Emails/stop/part9/8-872msg1.txt
# Emails/stop/part9/spmsgc51.txt
# Emails/stop/part9/9-1819msg1.txt
# Emails/stop/part9/9-517msg1.txt
# Emails/stop/part9/spmsgc52.txt
# Emails/stop/part9/9-441msg2.txt
# Emails/stop/part9/9-26msg1.txt
# Emails/stop/part9/9-461msg1.txt
# Emails/stop/part9/9-42msg1.txt
# Emails/stop/part9/9-587msg1.txt
# Emails/stop/part9/9-513msg1.txt
# Emails/stop/part9/9-552msg1.txt
# Emails/stop/part9/9-538msg1.txt
# Emails/stop/part9/9-418msg1.txt
# Emails/stop/part9/9-583msg2.txt
# Emails/stop/part9/9-542msg2.txt
# Emails/stop/part9/9-589msg1.txt
# Emails/stop/part9/9-55msg2.txt
# Emails/stop/part9/9-537msg1.txt
# Emails/stop/part9/spmsgc42.txt
# Emails/stop/part9/9-187msg1.txt
# Emails/stop/part9/9-1820msg1.txt
# Emails/stop/part9/9-519msg1.txt
# Emails/stop/part9/9-42msg2.txt
# Emails/stop/part9/spmsgc24.txt
# Emails/stop/part9/9-22msg1.txt
# Emails/stop/part9/9-575msg1.txt
# Emails/stop/part9/9-498msg2.txt
# Emails/stop/part9/8-923msg1.txt
# Emails/stop/part9/9-486msg1.txt
# Emails/stop/part9/spmsgc30.txt
# Emails/stop/part9/spmsgc26.txt
# Emails/stop/part9/9-571msg1.txt
# Emails/stop/part9/9-57msg2.txt
# Emails/stop/part9/9-528msg1.txt
# Emails/stop/part9/9-245msg1.txt
# Emails/stop/part9/9-568msg1.txt
# Emails/stop/part9/8-876msg1.txt
# Emails/stop/part9/spmsgc39.txt
# Emails/stop/part9/8-858msg1.txt
# Emails/stop/part9/9-472msg1.txt
# Emails/stop/part9/spmsgc32.txt
# Emails/stop/part9/9-244msg1.txt
# Emails/stop/part9/spmsgc145.txt
# Emails/stop/part9/8-863msg2.txt
# Emails/stop/part9/9-372msg2.txt
# Emails/stop/part9/9-353msg1.txt
# Emails/stop/part9/9-442msg1.txt
# Emails/stop/part9/9-415msg1.txt
# Emails/stop/part9/9-569msg1.txt
# Emails/stop/part9/spmsgc45.txt
# Emails/stop/part9/8-876msg2.txt
# Emails/stop/part9/spmsgc19.txt
# Emails/stop/part9/spmsgc16.txt
# Emails/stop/part9/8-817msg2.txt
# Emails/stop/part9/9-54msg2.txt
# Emails/stop/part9/9-3msg1.txt
# Emails/stop/part9/spmsgc53.txt
# Emails/stop/part9/9-512msg2.txt
# Emails/stop/part9/9-480msg1.txt
# Emails/stop/part9/9-385msg1.txt
# Emails/stop/part1/5-1240msg1.txt
# Emails/stop/part1/5-1258msg1.txt
# Emails/stop/part1/5-1243msg3.txt
# Emails/stop/part1/3-419msg1.txt
# Emails/stop/part1/5-1266msg2.txt
# Emails/stop/part1/3-383msg0.txt
# Emails/stop/part1/5-1242msg1.txt
# Emails/stop/part1/5-1275msg1.txt
# Emails/stop/part1/spmsga138.txt
# Emails/stop/part1/5-1288msg1.txt
# Emails/stop/part1/3-437msg4.txt
# Emails/stop/part1/3-426msg2.txt
# Emails/stop/part1/spmsga119.txt
# Emails/stop/part1/3-387msg1.txt
# Emails/stop/part1/3-402msg1.txt
# Emails/stop/part1/5-1230msg1.txt
# Emails/stop/part1/3-423msg3.txt
# Emails/stop/part1/5-1257msg3.txt
# Emails/stop/part1/3-559msg8.txt
# Emails/stop/part1/5-1255msg1.txt
# Emails/stop/part1/5-1285msg2.txt
# Emails/stop/part1/3-547msg1.txt
# Emails/stop/part1/spmsga125.txt
# Emails/stop/part1/3-395msg2.txt
# Emails/stop/part1/spmsga14.txt
# Emails/stop/part1/3-397msg1.txt
# Emails/stop/part1/3-387msg0.txt
# Emails/stop/part1/3-426msg3.txt
# Emails/stop/part1/3-405msg3.txt
# Emails/stop/part1/3-423msg2.txt
# Emails/stop/part1/5-1257msg1.txt
# Emails/stop/part1/3-390msg1.txt
# Emails/stop/part1/3-553msg2.txt
# Emails/stop/part1/3-378msg3.txt
# Emails/stop/part1/5-1256msg1.txt
# Emails/stop/part1/5-1218msg4.txt
# Emails/stop/part1/5-1221msg1.txt
# Emails/stop/part1/spmsga1.txt
# Emails/stop/part1/5-1296msg3.txt
# Emails/stop/part1/3-421msg4.txt
# Emails/stop/part1/spmsga140.txt
# Emails/stop/part1/3-430msg1.txt
# Emails/stop/part1/5-1245msg2.txt
# Emails/stop/part1/5-1268msg3.txt
# Emails/stop/part1/3-557msg2.txt
# Emails/stop/part1/3-388msg1.txt
# Emails/stop/part1/spmsga115.txt
# Emails/stop/part1/3-565msg2.txt
# Emails/stop/part1/3-384msg1.txt
# Emails/stop/part1/3-565msg1.txt
# Emails/stop/part1/spmsga113.txt
# Emails/stop/part1/3-421msg3.txt
# Emails/stop/part1/spmsga116.txt
# Emails/stop/part1/5-1225msg1.txt
# Emails/stop/part1/3-553msg3.txt
# Emails/stop/part1/spmsga107.txt
# Emails/stop/part1/3-392msg1.txt
# Emails/stop/part1/5-1215msg1.txt
# Emails/stop/part1/5-1225msg2.txt
# Emails/stop/part1/3-436msg3.txt
# Emails/stop/part1/3-423msg1.txt
# Emails/stop/part1/3-413msg1.txt
# Emails/stop/part1/3-404msg3.txt
# Emails/stop/part1/3-404msg2.txt
# Emails/stop/part1/3-553msg1.txt
# Emails/stop/part1/spmsga135.txt
# Emails/stop/part1/spmsga111.txt
# Emails/stop/part1/5-1278msg1.txt
# Emails/stop/part1/spmsga106.txt
# Emails/stop/part1/5-1264msg1.txt
# Emails/stop/part1/3-1msg1.txt
# Emails/stop/part1/3-380msg5.txt
# Emails/stop/part1/3-416msg5.txt
# Emails/stop/part1/spmsga124.txt
# Emails/stop/part1/3-387msg2.txt
# Emails/stop/part1/5-1290msg1.txt
# Emails/stop/part1/3-390msg2.txt
# Emails/stop/part1/3-550msg1.txt
# Emails/stop/part1/3-375msg1.txt
# Emails/stop/part1/3-384msg2.txt
# Emails/stop/part1/5-1271msg1.txt
# Emails/stop/part1/3-405msg1.txt
# Emails/stop/part1/3-445msg1.txt
# Emails/stop/part1/5-1243msg2.txt
# Emails/stop/part1/spmsga126.txt
# Emails/stop/part1/5-1293msg3.txt
# Emails/stop/part1/spmsga10.txt
# Emails/stop/part1/5-1213msg1.txt
# Emails/stop/part1/spmsga12.txt
# Emails/stop/part1/5-1261msg1.txt
# Emails/stop/part1/3-413msg2.txt
# Emails/stop/part1/3-390msg3.txt
# Emails/stop/part1/3-433msg3.txt
# Emails/stop/part1/3-411msg1.txt
# Emails/stop/part1/5-1268msg2.txt
# Emails/stop/part1/3-414msg2.txt
# Emails/stop/part1/3-391msg1.txt
# Emails/stop/part1/3-558msg1.txt
# Emails/stop/part1/3-379msg3.txt
# Emails/stop/part1/3-553msg0.txt
# Emails/stop/part1/5-1296msg2.txt
# Emails/stop/part1/3-415msg0.txt
# Emails/stop/part1/3-416msg3.txt
# Emails/stop/part1/3-398msg1.txt
# Emails/stop/part1/spmsga109.txt
# Emails/stop/part1/spmsga108.txt
# Emails/stop/part1/5-1217msg1.txt
# Emails/stop/part1/5-1285msg3.txt
# Emails/stop/part1/3-380msg7.txt
# Emails/stop/part1/3-559msg5.txt
# Emails/stop/part1/3-385msg2.txt
# Emails/stop/part1/3-559msg2.txt
# Emails/stop/part1/3-426msg1.txt
# Emails/stop/part1/5-1239msg3.txt
# Emails/stop/part1/3-437msg1.txt
# Emails/stop/part1/3-378msg1.txt
# Emails/stop/part1/3-384msg3.txt
# Emails/stop/part1/spmsga101.txt
# Emails/stop/part1/5-1227msg2.txt
# Emails/stop/part1/spmsga13.txt
# Emails/stop/part1/3-414msg1.txt
# Emails/stop/part1/spmsga100.txt
# Emails/stop/part1/3-444msg1.txt
# Emails/stop/part1/5-1219msg3.txt
# Emails/stop/part1/5-1279msg2.txt
# Emails/stop/part1/spmsga133.txt
# Emails/stop/part1/3-395msg1.txt
# Emails/stop/part1/3-442msg2.txt
# Emails/stop/part1/spmsga114.txt
# Emails/stop/part1/3-418msg1.txt
# Emails/stop/part1/spmsga129.txt
# Emails/stop/part1/5-1264msg3.txt
# Emails/stop/part1/5-1227msg1.txt
# Emails/stop/part1/3-390msg5.txt
# Emails/stop/part1/3-418msg2.txt
# Emails/stop/part1/3-425msg3.txt
# Emails/stop/part1/3-380msg4.txt
# Emails/stop/part1/5-1257msg2.txt
# Emails/stop/part1/5-1243msg1.txt
# Emails/stop/part1/3-436msg2.txt
# Emails/stop/part1/spmsga137.txt
# Emails/stop/part1/3-429msg0.txt
# Emails/stop/part1/3-421msg1.txt
# Emails/stop/part1/5-1236msg1.txt
# Emails/stop/part1/5-1285msg1.txt
# Emails/stop/part1/3-559msg1.txt
# Emails/stop/part1/3-559msg4.txt
# Emails/stop/part1/spmsga130.txt
# Emails/stop/part1/3-384msg0.txt
# Emails/stop/part1/5-1273msg1.txt
# Emails/stop/part1/5-1291msg3.txt
# Emails/stop/part1/5-1217msg3.txt
# Emails/stop/part1/5-1239msg1.txt
# Emails/stop/part1/5-1264msg2.txt
# Emails/stop/part1/5-1254msg1.txt
# Emails/stop/part1/5-1226msg1.txt
# Emails/stop/part1/5-1229msg1.txt
# Emails/stop/part1/5-1245msg1.txt
# Emails/stop/part1/5-1227msg3.txt
# Emails/stop/part1/3-405msg4.txt
# Emails/stop/part1/5-1217msg2.txt
# Emails/stop/part1/5-1293msg2.txt
# Emails/stop/part1/3-437msg5.txt
# Emails/stop/part1/3-559msg6.txt
# Emails/stop/part1/3-402msg2.txt
# Emails/stop/part1/5-1226msg3.txt
# Emails/stop/part1/3-390msg4.txt
# Emails/stop/part1/3-385msg1.txt
# Emails/stop/part1/spmsga139.txt
# Emails/stop/part1/5-1222msg2.txt
# Emails/stop/part1/5-1268msg1.txt
# Emails/stop/part1/3-563msg1.txt
# Emails/stop/part1/3-378msg5.txt
# Emails/stop/part1/5-1237msg1.txt
# Emails/stop/part1/spmsga105.txt
# Emails/stop/part1/3-422msg1.txt
# Emails/stop/part1/spmsga118.txt
# Emails/stop/part1/3-1msg3.txt
# Emails/stop/part1/spmsga123.txt
# Emails/stop/part1/5-1282msg2.txt
# Emails/stop/part1/5-1218msg1.txt
# Emails/stop/part1/3-425msg1.txt
# Emails/stop/part1/5-1266msg1.txt
# Emails/stop/part1/3-404msg4.txt
# Emails/stop/part1/spmsga104.txt
# Emails/stop/part1/5-1277msg1.txt
# Emails/stop/part1/3-416msg4.txt
# Emails/stop/part1/5-1293msg1.txt
# Emails/stop/part1/5-1211msg1.txt
# Emails/stop/part1/5-1245msg3.txt
# Emails/stop/part1/5-1251msg1.txt
# Emails/stop/part1/3-425msg2.txt
# Emails/stop/part1/5-1264msg5.txt
# Emails/stop/part1/5-1266msg3.txt
# Emails/stop/part1/5-1264msg4.txt
# Emails/stop/part1/5-1296msg1.txt
# Emails/stop/part1/3-404msg7.txt
# Emails/stop/part1/5-1219msg1.txt
# Emails/stop/part1/3-442msg1.txt
# Emails/stop/part1/3-404msg5.txt
# Emails/stop/part1/5-1291msg2.txt
# Emails/stop/part1/5-1286msg2.txt
# Emails/stop/part1/5-1225msg3.txt
# Emails/stop/part1/3-389msg1.txt
# Emails/stop/part1/5-1265msg1.txt
# Emails/stop/part1/spmsga122.txt
# Emails/stop/part1/5-1286msg3.txt
# Emails/stop/part1/3-559msg3.txt
# Emails/stop/part1/spmsga134.txt
# Emails/stop/part1/spmsga112.txt
# Emails/stop/part1/spmsga132.txt
# Emails/stop/part1/spmsga141.txt
# Emails/stop/part1/3-550msg2.txt
# Emails/stop/part1/spmsga136.txt
# Emails/stop/part1/3-404msg6.txt
# Emails/stop/part1/3-385msg3.txt
# Emails/stop/part1/3-392msg0.txt
# Emails/stop/part1/3-418msg3.txt
# Emails/stop/part1/5-1286msg1.txt
# Emails/stop/part1/3-413msg3.txt
# Emails/stop/part1/3-410msg1.txt
# Emails/stop/part1/3-380msg6.txt
# Emails/stop/part1/3-554msg2.txt
# Emails/stop/part1/3-378msg4.txt
# Emails/stop/part1/spmsga121.txt
# ...
# Emails/lemm/part6/9-1296msg1.txt
# Emails/lemm/part6/9-1677msg2.txt
# Emails/lemm/part6/9-1684msg1.txt
# Emails/lemm/part6/9-1416msg1.txt
# Emails/lemm/part6/9-1678msg1.txt
# Emails/lemm/part6/spmsgb24.txt
# Emails/lemm/part6/9-1602msg1.txt
# Emails/lemm/part6/9-1350msg1.txt
# Emails/lemm/part6/9-1276msg1.txt
# Emails/lemm/part6/9-15msg2.txt
# Emails/lemm/part6/9-1344msg1.txt
# Emails/lemm/part6/9-1689msg2.txt
# Emails/lemm/part6/9-1341msg1.txt
# Emails/lemm/part6/9-1404msg1.txt
# Emails/lemm/part6/9-1448msg1.txt
# Emails/lemm/part6/9-1652msg1.txt
# Emails/lemm/part6/9-1434msg1.txt
# Emails/lemm/part6/spmsgb35.txt
# Emails/lemm/part6/9-1311msg2.txt
# Emails/lemm/part6/9-1264msg1.txt
# Emails/lemm/part6/spmsgb18.txt
# Emails/lemm/part6/9-1354msg3.txt
# Emails/lemm/part6/9-1602msg2.txt
# Emails/lemm/part6/9-1543msg2.txt
# Emails/lemm/part6/9-162msg1.txt
# Emails/lemm/part6/9-1262msg1.txt
# Emails/lemm/part6/spmsgb30.txt
# Emails/lemm/part6/9-1515msg1.txt
# Emails/lemm/part6/9-1685msg1.txt
# Emails/lemm/part6/9-1304msg1.txt
# Emails/lemm/part6/spmsgb47.txt
# Emails/lemm/part6/9-126msg1.txt
# Emails/lemm/part6/9-1587msg1.txt
# Emails/lemm/part6/9-1300msg1.txt
# Emails/lemm/part6/9-1600msg1.txt
# Emails/lemm/part6/9-1342msg1.txt
# Emails/lemm/part6/9-1519msg2.txt
# Emails/lemm/part6/9-1593msg1.txt
# Emails/lemm/part6/9-1364msg1.txt
# Emails/lemm/part6/9-1354msg1.txt
# Emails/lemm/part6/9-1263msg1.txt
# Emails/lemm/part6/9-1543msg1.txt
# Emails/lemm/part6/9-1584msg1.txt
# Emails/lemm/part6/9-1648msg2.txt
# Emails/lemm/part6/9-1542msg1.txt
# Emails/lemm/part6/spmsgb50.txt
# Emails/lemm/part6/spmsgb2.txt
# Emails/lemm/part6/9-1481msg2.txt
# Emails/lemm/part6/9-1317msg1.txt
# Emails/lemm/part6/9-1597msg2.txt
# Emails/lemm/part6/9-142msg1.txt
# Emails/lemm/part6/spmsgb4.txt
# Emails/lemm/part6/spmsgb36.txt
# Emails/lemm/part6/9-1294msg1.txt
# Emails/lemm/part6/9-140msg1.txt
# Emails/lemm/part6/9-1376msg1.txt
# Emails/lemm/part6/9-1275msg1.txt
# Emails/lemm/part6/9-1377msg1.txt
# Emails/lemm/part6/9-1492msg1.txt
# Emails/lemm/part6/9-1622msg1.txt
# Emails/lemm/part6/9-128msg1.txt
# Emails/lemm/part6/9-1433msg1.txt
# Emails/lemm/part6/9-1485msg2.txt
# Emails/lemm/part6/spmsgb52.txt
# Emails/lemm/part6/spmsgb5.txt
# Emails/lemm/part6/9-1292msg1.txt
# Emails/lemm/part6/9-1602msg3.txt
# Emails/lemm/part6/9-1458msg2.txt
# Emails/lemm/part6/spmsgb23.txt
# Emails/lemm/part6/9-1418msg1.txt
# Emails/lemm/part6/9-1666msg1.txt
# Emails/lemm/part6/9-1560msg1.txt
# Emails/lemm/part6/9-147msg1.txt
# Emails/lemm/part6/9-1573msg1.txt
# Emails/lemm/part6/9-1603msg1.txt
# Emails/lemm/part6/9-1266msg2.txt
# Emails/lemm/part6/spmsgb41.txt
# Emails/lemm/part6/9-1326msg1.txt
# Emails/lemm/part6/9-1577msg2.txt
# Emails/lemm/part6/9-1401msg1.txt
# Emails/lemm/part6/9-1650msg2.txt
# Emails/lemm/part6/9-1669msg1.txt
# Emails/lemm/part6/9-1267msg2.txt
# Emails/lemm/part6/9-1632msg2.txt
# Emails/lemm/part6/9-1329msg1.txt
# Emails/lemm/part6/9-1564msg2.txt
# Emails/lemm/part6/9-1333msg1.txt
# Emails/lemm/part6/spmsgb166.txt
# Emails/lemm/part6/9-1546msg1.txt
# Emails/lemm/part6/9-1484msg1.txt
# Emails/lemm/part6/9-1274msg1.txt
# Emails/lemm/part6/9-1324msg1.txt
# Emails/lemm/part6/9-1590msg1.txt
# Emails/lemm/part6/9-1671msg1.txt
# Emails/lemm/part6/9-1266msg1.txt
# Emails/lemm/part6/9-1424msg1.txt
# Emails/lemm/part6/9-1410msg1.txt
# Emails/lemm/part6/9-1545msg1.txt
# Emails/lemm/part6/9-1627msg1.txt
# Emails/lemm/part6/9-1650msg1.txt
# Emails/lemm/part6/9-1367msg1.txt
# Emails/lemm/part6/spmsgb38.txt
# Emails/lemm/part6/9-1689msg1.txt
# Emails/lemm/part6/9-1577msg1.txt
# Emails/lemm/part6/spmsgb34.txt
# Emails/lemm/part6/spmsgb54.txt
# Emails/lemm/part6/9-1702msg1.txt
# Emails/lemm/part6/9-1516msg1.txt
# Emails/lemm/part6/9-1588msg1.txt
# Emails/lemm/part6/9-153msg1.txt
# Emails/lemm/part6/9-1646msg2.txt
# Emails/lemm/part6/spmsgb56.txt
# Emails/lemm/part6/9-15msg1.txt
# Emails/lemm/part6/9-1349msg1.txt
# Emails/lemm/part6/spmsgb32.txt
# Emails/lemm/part6/spmsgb43.txt
# Emails/lemm/part6/9-1699msg1.txt
# Emails/lemm/part6/9-1436msg1.txt
# Emails/lemm/part6/9-1545msg2.txt
# Emails/lemm/part6/9-1510msg1.txt
# Emails/lemm/part6/9-1542msg2.txt
# Emails/lemm/part6/9-1382msg1.txt
# Emails/lemm/part6/9-1699msg2.txt
# Emails/lemm/part6/9-1315msg1.txt
# Emails/lemm/part6/9-1336msg2.txt
# Emails/lemm/part6/9-1428msg1.txt
# Emails/lemm/part6/9-1623msg1.txt
# Emails/lemm/part6/9-1473msg1.txt
# Emails/lemm/part6/spmsgb39.txt
# Emails/lemm/part6/9-1403msg1.txt
# Emails/lemm/part6/9-159msg1.txt
# Emails/lemm/part6/9-1597msg1.txt
# Emails/lemm/part6/9-1465msg1.txt
# Emails/lemm/part6/spmsgb57.txt
# Emails/lemm/part6/9-1496msg1.txt
# Emails/lemm/part6/9-142msg2.txt
# Emails/lemm/part6/spmsgb167.txt
# Emails/lemm/part6/9-154msg1.txt
# Emails/lemm/part6/9-1586msg1.txt
# Emails/lemm/part6/9-138msg1.txt
# Emails/lemm/part6/spmsgb19.txt
# Emails/lemm/part6/spmsgb51.txt
# Emails/lemm/part6/9-1615msg1.txt
# Emails/lemm/part6/spmsgb21.txt
# Emails/lemm/part6/9-1267msg1.txt
# Emails/lemm/part6/9-1415msg1.txt
# Emails/lemm/part6/spmsgb44.txt
# Emails/lemm/part6/9-1362msg1.txt
# Emails/lemm/part6/9-133msg1.txt
# Emails/lemm/part6/9-1295msg1.txt
# Emails/lemm/part6/9-126msg2.txt
# Emails/lemm/part6/spmsgb3.txt
# Emails/lemm/part6/9-1670msg1.txt
# Emails/lemm/part6/9-1458msg1.txt
# Emails/lemm/part6/9-1392msg1.txt
# Emails/lemm/part6/9-1301msg1.txt
# Emails/lemm/part6/spmsgb29.txt
# Emails/lemm/part6/9-1593msg2.txt
# Emails/lemm/part6/spmsgb27.txt
# Emails/lemm/part6/spmsgb20.txt
# Emails/lemm/part6/9-1424msg2.txt
# Emails/lemm/part6/9-1585msg1.txt
# Emails/lemm/part6/9-1473msg2.txt
# Emails/lemm/part6/9-1691msg1.txt
# Emails/lemm/part6/9-1289msg1.txt
# Emails/lemm/part6/spmsgb33.txt
# Emails/lemm/part6/9-1515msg2.txt
# Emails/lemm/part6/9-1546msg2.txt
# Emails/lemm/part6/spmsgb25.txt
# Emails/lemm/part6/9-1680msg1.txt
# Emails/lemm/part6/9-1566msg2.txt
# Emails/lemm/part6/9-1354msg2.txt
# Emails/lemm/part6/9-1290msg1.txt
# Emails/lemm/part6/9-1389msg1.txt
# Emails/lemm/part6/9-1316msg1.txt
# Emails/lemm/part6/9-1632msg1.txt
# Emails/lemm/part6/9-1307msg1.txt
# Emails/lemm/part6/9-1536msg1.txt
# Emails/lemm/part6/spmsgb46.txt
# Emails/lemm/part6/9-1414msg1.txt
# Emails/lemm/part6/9-1373msg1.txt
# Emails/lemm/part6/9-1527msg2.txt
# Emails/lemm/part6/9-1400msg1.txt
# Emails/lemm/part6/9-1530msg2.txt
# Emails/lemm/part6/spmsgb26.txt
# Emails/lemm/part6/9-1429msg1.txt
# Emails/lemm/part6/9-1607msg1.txt
# Emails/lemm/part6/9-1484msg2.txt
# Emails/lemm/part6/9-1527msg1.txt
# Emails/lemm/part6/9-1329msg2.txt
# Emails/lemm/part6/9-1444msg1.txt
# Emails/lemm/part6/spmsgb31.txt
# Emails/lemm/part6/9-1343msg1.txt
# Emails/lemm/part6/9-1293msg1.txt
# Emails/lemm/part6/spmsgb53.txt
# Emails/lemm/part6/9-1400msg2.txt
# Emails/lemm/part6/9-1563msg2.txt
# Emails/lemm/part6/9-1646msg1.txt
# Emails/lemm/part6/9-1443msg1.txt
# Emails/lemm/part6/9-1604msg1.txt
# Emails/lemm/part6/9-133msg2.txt
# Emails/lemm/part5/9-1188msg1.txt
# Emails/lemm/part5/spmsgb148.txt
# Emails/lemm/part5/spmsgb122.txt
# Emails/lemm/part5/8-896msg1.txt
# Emails/lemm/part5/9-1259msg1.txt
# Emails/lemm/part5/9-1030msg1.txt
# Emails/lemm/part5/8-905msg1.txt
# Emails/lemm/part5/9-1144msg1.txt
# Emails/lemm/part5/9-1153msg2.txt
# Emails/lemm/part5/8-987msg2.txt
# Emails/lemm/part5/9-1208msg1.txt
# Emails/lemm/part5/9-1043msg2.txt
# Emails/lemm/part5/spmsgb132.txt
# Emails/lemm/part5/9-1022msg1.txt
# Emails/lemm/part5/8-894msg1.txt
# Emails/lemm/part5/spmsgb131.txt
# Emails/lemm/part5/9-111msg1.txt
# Emails/lemm/part5/spmsgb144.txt
# Emails/lemm/part5/9-1258msg2.txt
# Emails/lemm/part5/8-865msg2.txt
# Emails/lemm/part5/9-1217msg1.txt
# Emails/lemm/part5/9-1199msg2.txt
# Emails/lemm/part5/8-833msg1.txt
# Emails/lemm/part5/9-1200msg1.txt
# Emails/lemm/part5/9-1140msg1.txt
# Emails/lemm/part5/9-1004msg1.txt
# Emails/lemm/part5/9-1002msg1.txt
# Emails/lemm/part5/9-1243msg1.txt
# Emails/lemm/part5/9-1119msg1.txt
# Emails/lemm/part5/spmsgb15.txt
# Emails/lemm/part5/9-1066msg1.txt
# Emails/lemm/part5/8-871msg1.txt
# Emails/lemm/part5/8-1242msg1.txt
# Emails/lemm/part5/9-1073msg2.txt
# Emails/lemm/part5/8-838msg1.txt
# Emails/lemm/part5/9-1073msg1.txt
# Emails/lemm/part5/8-837msg2.txt
# Emails/lemm/part5/8-897msg1.txt
# Emails/lemm/part5/9-118msg2.txt
# Emails/lemm/part5/spmsgb156.txt
# Emails/lemm/part5/8-845msg1.txt
# Emails/lemm/part5/9-1184msg1.txt
# Emails/lemm/part5/9-1001msg1.txt
# Emails/lemm/part5/9-1077msg1.txt
# Emails/lemm/part5/9-1128msg1.txt
# Emails/lemm/part5/8-898msg1.txt
# Emails/lemm/part5/9-1034msg1.txt
# Emails/lemm/part5/9-1172msg2.txt
# Emails/lemm/part5/9-1086msg1.txt
# Emails/lemm/part5/9-1230msg1.txt
# Emails/lemm/part5/8-835msg1.txt
# Emails/lemm/part5/spmsgb163.txt
# Emails/lemm/part5/9-1102msg2.txt
# Emails/lemm/part5/9-1012msg1.txt
# Emails/lemm/part5/8-899msg1.txt
# Emails/lemm/part5/spmsgb125.txt
# Emails/lemm/part5/8-951msg1.txt
# Emails/lemm/part5/8-862msg1.txt
# Emails/lemm/part5/9-1249msg1.txt
# Emails/lemm/part5/9-1067msg1.txt
# Emails/lemm/part5/spmsgb165.txt
# Emails/lemm/part5/8-963msg1.txt
# Emails/lemm/part5/9-1088msg1.txt
# Emails/lemm/part5/9-1228msg1.txt
# Emails/lemm/part5/9-1122msg1.txt
# Emails/lemm/part5/9-1121msg1.txt
# Emails/lemm/part5/8-1239msg1.txt
# Emails/lemm/part5/9-1111msg1.txt
# Emails/lemm/part5/spmsgb147.txt
# Emails/lemm/part5/9-1231msg1.txt
# Emails/lemm/part5/8-815msg1.txt
# Emails/lemm/part5/8-1214msg1.txt
# Emails/lemm/part5/spmsgb137.txt
# Emails/lemm/part5/9-1138msg1.txt
# Emails/lemm/part5/9-1087msg1.txt
# Emails/lemm/part5/8-811msg1.txt
# Emails/lemm/part5/spmsgb157.txt
# Emails/lemm/part5/9-1244msg1.txt
# Emails/lemm/part5/spmsgb160.txt
# Emails/lemm/part5/8-840msg1.txt
# Emails/lemm/part5/9-1190msg1.txt
# Emails/lemm/part5/9-1191msg1.txt
# Emails/lemm/part5/8-814msg1.txt
# Emails/lemm/part5/9-1192msg1.txt
# Emails/lemm/part5/9-1055msg1.txt
# Emails/lemm/part5/8-865msg3.txt
# Emails/lemm/part5/9-1115msg1.txt
# Emails/lemm/part5/9-124msg1.txt
# Emails/lemm/part5/9-1008msg1.txt
# Emails/lemm/part5/9-1226msg2.txt
# Emails/lemm/part5/spmsgb14.txt
# Emails/lemm/part5/9-1033msg1.txt
# Emails/lemm/part5/8-811msg2.txt
# Emails/lemm/part5/9-1099msg2.txt
# Emails/lemm/part5/8-905msg2.txt
# Emails/lemm/part5/9-1239msg1.txt
# Emails/lemm/part5/9-1260msg1.txt
# Emails/lemm/part5/9-1026msg1.txt
# Emails/lemm/part5/9-1157msg1.txt
# Emails/lemm/part5/8-972msg1.txt
# Emails/lemm/part5/9-120msg1.txt
# Emails/lemm/part5/9-1099msg1.txt
# Emails/lemm/part5/9-1116msg2.txt
# Emails/lemm/part5/9-1221msg1.txt
# Emails/lemm/part5/9-1218msg1.txt
# Emails/lemm/part5/8-865msg1.txt
# Emails/lemm/part5/8-963msg2.txt
# Emails/lemm/part5/9-1044msg1.txt
# Emails/lemm/part5/8-949msg2.txt
# Emails/lemm/part5/spmsgb154.txt
# Emails/lemm/part5/9-1261msg1.txt
# Emails/lemm/part5/9-1206msg1.txt
# Emails/lemm/part5/9-1160msg1.txt
# Emails/lemm/part5/8-809msg1.txt
# Emails/lemm/part5/spmsgb149.txt
# Emails/lemm/part5/9-1155msg1.txt
# Emails/lemm/part5/8-1245msg1.txt
# Emails/lemm/part5/9-1020msg1.txt
# Emails/lemm/part5/8-965msg1.txt
# Emails/lemm/part5/9-1070msg1.txt
# Emails/lemm/part5/9-1058msg1.txt
# Emails/lemm/part5/9-108msg1.txt
# Emails/lemm/part5/8-1211msg1.txt
# Emails/lemm/part5/8-900msg1.txt
# Emails/lemm/part5/9-1232msg1.txt
# Emails/lemm/part5/9-1064msg1.txt
# Emails/lemm/part5/spmsgb16.txt
# Emails/lemm/part5/9-1128msg2.txt
# Emails/lemm/part5/9-103msg1.txt
# Emails/lemm/part5/9-1077msg2.txt
# Emails/lemm/part5/9-1252msg1.txt
# Emails/lemm/part5/9-1105msg1.txt
# Emails/lemm/part5/9-1021msg1.txt
# Emails/lemm/part5/9-1112msg1.txt
# Emails/lemm/part5/9-1226msg1.txt
# Emails/lemm/part5/9-1037msg1.txt
# Emails/lemm/part5/9-1163msg2.txt
# Emails/lemm/part5/9-1040msg1.txt
# Emails/lemm/part5/spmsgb159.txt
# Emails/lemm/part5/spmsgb158.txt
# Emails/lemm/part5/9-1156msg1.txt
# Emails/lemm/part5/8-893msg1.txt
# Emails/lemm/part5/9-118msg1.txt
# Emails/lemm/part5/9-125msg1.txt
# Emails/lemm/part5/9-1243msg2.txt
# Emails/lemm/part5/9-1020msg2.txt
# Emails/lemm/part5/9-1116msg1.txt
# Emails/lemm/part5/9-1134msg1.txt
# Emails/lemm/part5/spmsgb151.txt
# Emails/lemm/part5/8-1182msg1.txt
# Emails/lemm/part5/9-1139msg1.txt
# Emails/lemm/part5/spmsgb145.txt
# Emails/lemm/part5/8-1214msg2.txt
# Emails/lemm/part5/9-1172msg1.txt
# Emails/lemm/part5/9-1251msg1.txt
# Emails/lemm/part5/9-1017msg1.txt
# Emails/lemm/part5/9-1225msg1.txt
# Emails/lemm/part5/9-1033msg2.txt
# Emails/lemm/part5/9-1195msg1.txt
# Emails/lemm/part5/9-109msg1.txt
# Emails/lemm/part5/8-873msg1.txt
# Emails/lemm/part5/9-1258msg1.txt
# Emails/lemm/part5/spmsgb129.txt
# Emails/lemm/part5/8-949msg1.txt
# Emails/lemm/part5/spmsgb126.txt
# Emails/lemm/part5/9-1036msg1.txt
# Emails/lemm/part5/8-1215msg1.txt
# Emails/lemm/part5/9-1195msg2.txt
# Emails/lemm/part5/9-1152msg1.txt
# Emails/lemm/part5/9-1177msg1.txt
# Emails/lemm/part5/spmsgb146.txt
# Emails/lemm/part5/9-1199msg1.txt
# Emails/lemm/part5/9-1251msg2.txt
# Emails/lemm/part5/spmsgb161.txt
# Emails/lemm/part5/spmsgb136.txt
# Emails/lemm/part5/9-1065msg1.txt
# Emails/lemm/part5/9-1143msg1.txt
# Emails/lemm/part5/9-106msg1.txt
# Emails/lemm/part5/spmsgb153.txt
# Emails/lemm/part5/9-1038msg1.txt
# Emails/lemm/part5/9-1039msg1.txt
# Emails/lemm/part5/8-887msg2.txt
# Emails/lemm/part5/9-1222msg1.txt
# Emails/lemm/part5/spmsgb127.txt
# Emails/lemm/part5/9-1017msg2.txt
# Emails/lemm/part5/9-1110msg1.txt
# Emails/lemm/part5/spmsgb139.txt
# Emails/lemm/part5/9-1043msg1.txt
# Emails/lemm/part5/9-1165msg1.txt
# Emails/lemm/part5/9-1145msg1.txt
# Emails/lemm/part5/9-1091msg1.txt
# Emails/lemm/part5/spmsgb162.txt
# Emails/lemm/part5/9-1029msg1.txt
# Emails/lemm/part5/9-1164msg1.txt
# Emails/lemm/part5/8-887msg1.txt
# Emails/lemm/part5/8-1182msg2.txt
# Emails/lemm/part5/9-1113msg1.txt
# Emails/lemm/part5/8-984msg1.txt
# Emails/lemm/part5/9-1114msg1.txt
# Emails/lemm/part5/spmsgb143.txt
# Emails/lemm/part5/9-106msg2.txt
# Emails/lemm/part5/9-110msg1.txt
# Emails/lemm/part5/spmsgb142.txt
# Emails/lemm/part5/spmsgb134.txt
# Emails/lemm/part5/9-1082msg2.txt
# Emails/lemm/part5/9-1045msg1.txt
# Emails/lemm/part5/8-1231msg1.txt
# Emails/lemm/part5/9-1047msg1.txt
# Emails/lemm/part5/9-101msg2.txt
# Emails/lemm/part5/9-1207msg1.txt
# Emails/lemm/part5/9-1097msg1.txt
# Emails/lemm/part5/9-1125msg1.txt
# Emails/lemm/part5/9-1078msg1.txt
# Emails/lemm/part5/9-1082msg1.txt
# Emails/lemm/part5/9-1074msg1.txt
# Emails/lemm/part5/9-1246msg1.txt
# Emails/lemm/part5/8-1204msg1.txt
# Emails/lemm/part5/9-1133msg1.txt
# Emails/lemm/part5/9-1085msg1.txt
# Emails/lemm/part5/spmsgb135.txt
# Emails/lemm/part5/9-1240msg1.txt
# Emails/lemm/part5/9-1089msg1.txt
# Emails/lemm/part5/spmsgb164.txt
# Emails/lemm/part5/9-1219msg1.txt
# Emails/lemm/part5/9-1215msg1.txt
# Emails/lemm/part5/9-1137msg1.txt
# Emails/lemm/part5/9-1158msg1.txt
# Emails/lemm/part5/9-1102msg1.txt
# Emails/lemm/part5/spmsgb128.txt
# Emails/lemm/part5/9-1220msg1.txt
# Emails/lemm/part5/9-1135msg1.txt
# Emails/lemm/part5/9-119msg1.txt
# Emails/lemm/part5/9-1014msg1.txt
# Emails/lemm/part5/8-885msg1.txt
# Emails/lemm/part5/9-1236msg1.txt
# Emails/lemm/part5/9-1146msg1.txt
# Emails/lemm/part5/9-1154msg1.txt
# Emails/lemm/part5/9-1163msg1.txt
# Emails/lemm/part5/9-1208msg2.txt
# Emails/lemm/part5/9-1118msg1.txt
# Emails/lemm/part5/9-1098msg1.txt
# Emails/lemm/part5/8-846msg1.txt
# Emails/lemm/part5/spmsgb155.txt
# Emails/lemm/part5/9-1072msg1.txt
# Emails/lemm/part5/9-1253msg1.txt
# Emails/lemm/part5/9-1244msg2.txt
# Emails/lemm/part5/9-1069msg1.txt
# Emails/lemm/part5/9-1104msg1.txt
# Emails/lemm/part5/spmsgb150.txt
# Emails/lemm/part5/9-1254msg1.txt
# Emails/lemm/part5/9-101msg1.txt
# Emails/lemm/part5/spmsgb140.txt
# Emails/lemm/part5/8-916msg1.txt
# Emails/lemm/part5/spmsgb141.txt
# Emails/lemm/part5/spmsgb138.txt
# Emails/lemm/part5/9-1141msg1.txt
# Emails/lemm/part5/9-1090msg1.txt
# Emails/lemm/part5/9-1009msg1.txt
# Emails/lemm/part5/8-895msg1.txt
# Emails/lemm/part5/9-1045msg2.txt
# Emails/lemm/part5/9-1193msg1.txt
# Emails/lemm/part5/spmsgb133.txt
# Emails/lemm/part5/9-1162msg1.txt
# Emails/lemm/part5/spmsgb13.txt
# Emails/lemm/part5/spmsgb123.txt
# Emails/lemm/part5/9-1080msg1.txt
# Emails/lemm/part5/spmsgb124.txt
# Emails/lemm/part5/spmsgb130.txt
# Emails/lemm/part5/9-1035msg1.txt
# Emails/lemm/part5/9-1062msg1.txt
# Emails/lemm/part5/9-1238msg1.txt
# Emails/lemm/part5/8-837msg1.txt
# Emails/lemm/part5/9-1161msg1.txt
# Emails/lemm/part5/9-1003msg1.txt
# Emails/lemm/part5/9-1011msg1.txt
# Emails/lemm/part5/9-114msg1.txt
# Emails/lemm/part5/9-1142msg1.txt
# Emails/lemm/part5/9-1153msg1.txt
# Emails/lemm/part5/9-1100msg1.txt
# Emails/lemm/part5/8-965msg2.txt
# Emails/lemm/part5/9-1080msg2.txt
# Emails/lemm/part5/spmsgb152.txt
# Emails/lemm/part5/8-875msg1.txt
# Emails/lemm/part5/8-972msg2.txt
# Emails/lemm/part5/8-838msg2.txt
# Emails/lemm/part5/8-901msg1.txt
# Emails/lemm/part5/8-987msg1.txt
# Emails/lemm/part5/9-1123msg1.txt
# Emails/lemm/part5/9-1216msg1.txt
# Emails/lemm/part5/9-114msg2.txt
